# %%
from collections import Counter
import time, datetime, CaboCha, random,MeCab
import pandas as pd, glob, os

cp = CaboCha.Parser()
white = '/home/ichikawa17/01_yahooScraping/'

# %%
for p in glob.glob(white+'/02*/*.csv', recursive=True):
    i=0
    print(os.path.basename(p))
# Out:
# 09211414緊急事態宣言　全面解除視野に検討　28日に決定へ.csv
# 06281642梶山経産相、キャリア職員逮捕で陳謝　コロナ給付金詐欺事件.csv
# 07011434あすにかけ東・西日本で大雨　厳重警戒を.csv
# 09211340緊急事態宣言　全面解除視野に検討　28日に決定へ.csv

# %%
# !pwd
# Out:
# /home/ichikawa17/01_yahooScraping/00_Codes

# %%
with open(os.path.base, mode='rt', encoding='utf-8') as f:
    read_text = f.read()
comment_txt = read_text
print(comment_txt)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-c2e83f44eacf> in <module>
# ----> 1 with open('/home/01_yahooScraping/02_NewsComment/09211340緊急事態宣言　全面解除視野に検討　28日に決定へ.csv', mode='rt', encoding='utf-8') as f:
#       2     read_text = f.read()
#       3 comment_txt = read_text
#       4 print(comment_txt)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/01_yahooScraping/02_NewsComment/09211340緊急事態宣言\u3000全面解除視野に検討\u300028日に決定へ.csv'

# %%
tagger = MeCab.Tagger("-Owakati")

# %%
df_NCs = pd.read_csv(white+'/02_NewsComment/'+os.path.basename(p))
df_words = pd.DataFrame(columns=['原型','品詞','出現数'])
df_parses = []
# tree = cp.parse(df_NCs['コメント'][0][0])
# print(tree.toString(CaboCha.FORMAT_LATTICE))



for df_NC in df_NCs['コメント']:
    tree = cp.parse(df_NC)
    df_parses += tree.toString(CaboCha.FORMAT_LATTICE).split('\n')

# %%
df = []
for df_parse in df_parses:
    print(df_parse)
    if not df_parse.startswith():
        df += df_parse
# Out:
# * 0 -1D 1/1 0.000000
# う	感動詞,*,*,*,*,*,う,ウ,ウ
# ひょ〜	副詞,一般,*,*,*,*,ひょー,ヒョー,ヒョー
# EOS
#
# * 0 1D 0/1 1.079874
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 1 3D 0/1 1.305735
# 伴っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,伴う,トモナッ,トモナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 2 3D 0/1 2.949192
# 気温	名詞,一般,*,*,*,*,気温,キオン,キオン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 3 6D 1/4 -1.441601
# 低下	名詞,サ変接続,*,*,*,*,低下,テイカ,テイカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# * 4 6D 0/2 -1.441601
# 体調	名詞,一般,*,*,*,*,体調,タイチョウ,タイチョー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 5 6D 0/1 -1.441601
# 気	名詞,一般,*,*,*,*,気,キ,キ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 6 -1D 0/2 0.000000
# つけ	動詞,自立,*,*,一段,連用形,つける,ツケ,ツケ
# ましょ	助動詞,*,*,*,特殊・マス,未然ウ接続,ます,マショ,マショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# EOS
#
# * 0 1D 1/2 1.504718
# 該当	名詞,サ変接続,*,*,*,*,該当,ガイトウ,ガイトー
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# * 1 7D 0/1 -1.906418
# 地域	名詞,一般,*,*,*,*,地域,チイキ,チイキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 2 3D 1/2 2.775941
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 住まい	名詞,一般,*,*,*,*,住まい,スマイ,スマイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 3 7D 0/1 -1.906418
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# * 4 6D 1/2 1.781078
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 5 6D 0/1 2.159416
# 準備	名詞,サ変接続,*,*,*,*,準備,ジュンビ,ジュンビ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# * 6 7D 0/2 -1.906418
# 避難	名詞,サ変接続,*,*,*,*,避難,ヒナン,ヒナン
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 7 -1D 0/2 0.000000
# 心がけ	動詞,自立,*,*,一段,連用形,心がける,ココロガケ,ココロガケ
# ましょ	助動詞,*,*,*,特殊・マス,未然ウ接続,ます,マショ,マショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 3D 0/0 -1.011285
# またもや	副詞,一般,*,*,*,*,またもや,マタモヤ,マタモヤ
# 、	記号,読点,*,*,*,*,、,、,、
# * 1 3D 0/1 -1.011285
# あれ	名詞,代名詞,一般,*,*,*,あれ,アレ,アレ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 、	記号,読点,*,*,*,*,、,、,、
# * 2 3D 0/1 -1.011285
# 悪夢	名詞,一般,*,*,*,*,悪夢,アクム,アクム
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 3 -1D 0/0 0.000000
# 蘇る	動詞,自立,*,*,五段・ラ行,基本形,蘇る,ヨミガエル,ヨミガエル
# EOS
#
# * 0 3D 1/2 1.238705
# 技術	名詞,一般,*,*,*,*,技術,ギジュツ,ギジュツ
# 進歩	名詞,サ変接続,*,*,*,*,進歩,シンポ,シンポ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 1 3D 0/0 0.953665
# こうして	接続詞,*,*,*,*,*,こうして,コウシテ,コーシテ
# * 2 3D 0/1 1.848011
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 3 6D 1/4 1.794074
# アナウンス	名詞,サ変接続,*,*,*,*,アナウンス,アナウンス,アナウンス
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれる	動詞,非自立,*,*,一段・クレル,基本形,くれる,クレル,クレル
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 4 5D 0/1 1.646749
# 事前	名詞,一般,*,*,*,*,事前,ジゼン,ジゼン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 5 6D 0/1 1.538683
# 備え	名詞,一般,*,*,*,*,備え,ソナエ,ソナエ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 6 7D 0/1 1.858039
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# * 7 10D 0/2 -1.828106
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# * 8 9D 0/0 0.037985
# とにかく	副詞,一般,*,*,*,*,とにかく,トニカク,トニカク
# * 9 10D 1/2 -1.828106
# 皆さん	名詞,一般,*,*,*,*,皆さん,ミナサン,ミナサン
# 無事	名詞,形容動詞語幹,*,*,*,*,無事,ブジ,ブジ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# * 10 -1D 2/3 0.000000
# 乗り切れ	動詞,自立,*,*,一段,連用形,乗り切れる,ノリキレ,ノリキレ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 3D 0/0 -0.815235
# 兎に角	副詞,一般,*,*,*,*,兎に角,トニカク,トニカク
# 、	記号,読点,*,*,*,*,、,、,、
# * 1 3D 0/1 -0.815235
# 避難	名詞,サ変接続,*,*,*,*,避難,ヒナン,ヒナン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 2 3D 0/2 -0.815235
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 3 -1D 0/1 0.000000
# 肝心	名詞,形容動詞語幹,*,*,*,*,肝心,カンジン,カンジン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 5D 0/0 2.054586
# 毎日	名詞,副詞可能,*,*,*,*,毎日,マイニチ,マイニチ
# 、	記号,読点,*,*,*,*,、,、,、
# * 1 5D 0/1 2.577033
# 各地	名詞,一般,*,*,*,*,各地,カクチ,カクチ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 2 3D 0/1 1.489336
# 同様	名詞,形容動詞語幹,*,*,*,*,同様,ドウヨウ,ドーヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 3 5D 0/1 3.197832
# ニュース	名詞,一般,*,*,*,*,ニュース,ニュース,ニュース
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 4 5D 0/1 3.719495
# 耳	名詞,一般,*,*,*,*,耳,ミミ,ミミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 5 10D 0/1 0.330945
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# * 6 10D 0/3 1.216873
# 大風	名詞,形容動詞語幹,*,*,*,*,大風,オオフウ,オーフー
# でも	助詞,副助詞,*,*,*,*,でも,デモ,デモ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# のに	助詞,接続助詞,*,*,*,*,のに,ノニ,ノニ
# * 7 9D 0/1 0.788264
# 短時間	名詞,副詞可能,*,*,*,*,短時間,タンジカン,タンジカン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 8 9D 0/1 1.812860
# 想定	名詞,サ変接続,*,*,*,*,想定,ソウテイ,ソーテイ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 9 10D 0/0 1.858202
# 超える	動詞,自立,*,*,一段,基本形,超える,コエル,コエル
# * 10 19D 0/0 0.827693
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# 。	記号,句点,*,*,*,*,。,。,。
# * 11 12D 0/1 0.341200
# 地域	名詞,一般,*,*,*,*,地域,チイキ,チイキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 12 19D 0/0 1.250157
# 皆さん	名詞,一般,*,*,*,*,皆さん,ミナサン,ミナサン
# 、	記号,読点,*,*,*,*,、,、,、
# * 13 14D 0/1 1.949241
# ハザードマップ	名詞,固有名詞,一般,*,*,*,ハザードマップ,ハザードマップ,ハザードマップ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 14 16D 1/1 0.999923
# 確認	名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# * 15 16D 0/1 1.598865
# 避難指示	名詞,固有名詞,一般,*,*,*,避難指示,ヒナンシジ,ヒナンシジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 16 19D 0/1 2.814509
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# たら	助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ
# * 17 18D 0/1 1.594414
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 18 19D 0/1 3.575814
# 避難	名詞,サ変接続,*,*,*,*,避難,ヒナン,ヒナン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 19 27D 0/2 -1.117109
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 下さい	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,下さる,クダサイ,クダサイ
# 。	記号,句点,*,*,*,*,。,。,。
# * 20 27D 0/0 -1.117109
# また	接続詞,*,*,*,*,*,また,マタ,マタ
# 、	記号,読点,*,*,*,*,、,、,、
# * 21 27D 1/2 -1.117109
# 最低	名詞,一般,*,*,*,*,最低,サイテイ,サイテイ
# 3日間	名詞,固有名詞,一般,*,*,*,3日間,ミッカ,ミッカ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 22 24D 0/0 1.575877
# 過ごせる	動詞,自立,*,*,一段,基本形,過ごせる,スゴセル,スゴセル
# * 23 24D 0/1 1.318887
# 水	名詞,一般,*,*,*,*,水,ミズ,ミズ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# * 24 26D 0/1 1.238585
# 食料	名詞,一般,*,*,*,*,食料,ショクリョウ,ショクリョー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 25 26D 7/8 1.707039
# 準備	名詞,サ変接続,*,*,*,*,準備,ジュンビ,ジュンビ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おか	動詞,自立,*,*,五段・カ行イ音便,未然形,おく,オカ,オカ
# なけれ	助動詞,*,*,*,特殊・ナイ,仮定形,ない,ナケレ,ナケレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# …	記号,一般,*,*,*,*,…,…,…
# 大災害	名詞,固有名詞,一般,*,*,*,大災害,ダイサイガイ,ダイサイガイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 26 27D 0/2 -1.117109
# なら	動詞,自立,*,*,五段・ラ行,未然形,なる,ナラ,ナラ
# なけれ	助動詞,*,*,*,特殊・ナイ,仮定形,ない,ナケレ,ナケレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# * 27 -1D 1/3 0.000000
# 良い	形容詞,非自立,*,*,形容詞・アウオ段,基本形,良い,ヨイ,ヨイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/0 1.216842
# こういう	連体詞,*,*,*,*,*,こういう,コウイウ,コーユウ
# * 1 3D 0/1 1.997509
# 時	名詞,非自立,副詞可能,*,*,*,時,トキ,トキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 2 3D 0/1 1.604330
# 天気予報	名詞,固有名詞,一般,*,*,*,天気予報,テンキヨホウ,テンキヨホー
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# * 3 7D 0/1 -0.870513
# ニュース	名詞,一般,*,*,*,*,ニュース,ニュース,ニュース
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 4 5D 0/1 1.321620
# 皆様	名詞,一般,*,*,*,*,皆様,ミナサマ,ミナサマ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 5 6D 0/1 1.491253
# NHK	名詞,固有名詞,一般,*,*,*,NHK,エヌエイチケイ,エヌエイチケイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 6 7D 0/1 -0.870513
# 頼る	動詞,自立,*,*,五段・ラ行,基本形,頼る,タヨル,タヨル
# しか	助詞,係助詞,*,*,*,*,しか,シカ,シカ
# * 7 -1D 0/0 0.000000
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# EOS
#
# * 0 1D 0/0 1.896461
# 危ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,危ない,アブナイ,アブナイ
# * 1 2D 0/1 1.495349
# 所	名詞,非自立,副詞可能,*,*,*,所,トコロ,トコロ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 2 3D 0/1 2.017221
# 住ん	動詞,自立,*,*,五段・マ行,連用タ接続,住む,スン,スン
# でる	動詞,非自立,*,*,一段,基本形,でる,デル,デル
# * 3 7D 0/1 -1.317446
# 人達	名詞,一般,*,*,*,*,人達,ヒトタチ,ヒトタチ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# * 4 5D 0/1 1.975374
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 5 6D 1/4 2.480556
# 避難	名詞,サ変接続,*,*,*,*,避難,ヒナン,ヒナン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おい	動詞,非自立,*,*,五段・カ行イ音便,連用タ接続,おく,オイ,オイ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 6 7D 0/1 -1.317446
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 7 -1D 0/1 0.000000
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# かも	助詞,副助詞,*,*,*,*,かも,カモ,カモ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 2.247886
# 気候変動	名詞,固有名詞,一般,*,*,*,気候変動,キコウヘンドウ,キコーヘンドー
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# * 1 9D 2/5 -1.924787
# 起こっ	動詞,自立,*,*,五段・ラ行,連用タ接続,起こる,オコッ,オコッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# * 2 3D 2/3 2.085986
# 思う	動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# 広島	名詞,固有名詞,地域,一般,*,*,広島,ヒロシマ,ヒロシマ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 3 9D 0/2 -1.924787
# 山	名詞,一般,*,*,*,*,山,ヤマ,ヤマ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 4 6D 0/1 0.676582
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 5 6D 0/1 1.611309
# ゲリラ豪雨	名詞,固有名詞,一般,*,*,*,ゲリラ豪雨,ゲリラゴウウ,ゲリラゴウー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 6 7D 0/1 1.486133
# 削れ	動詞,自立,*,*,一段,連用形,削れる,ケズレ,ケズレ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 7 9D 0/1 -1.924787
# あと	名詞,一般,*,*,*,*,あと,アト,アト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 8 9D 0/0 -1.924787
# 多数	名詞,副詞可能,*,*,*,*,多数,タスウ,タスー
# * 9 -1D 0/2 0.000000
# 見	動詞,自立,*,*,一段,未然形,見る,ミ,ミ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# EOS
#
# * 0 1D 0/1 1.748123
# 全国	名詞,一般,*,*,*,*,全国,ゼンコク,ゼンコク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 2D 1/2 3.766319
# ニュース	名詞,一般,*,*,*,*,ニュース,ニュース,ニュース
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 2 3D 1/2 1.518853
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# * 3 6D 0/1 1.480961
# 強い	形容詞,自立,*,*,形容詞・アウオ段,基本形,強い,ツヨイ,ツヨイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# * 4 6D 2/3 2.102469
# ↓	記号,一般,*,*,*,*,↓,↓,↓
# 今	接頭詞,名詞接続,*,*,*,*,今,コン,コン
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 5 6D 0/1 4.241249
# 九州	名詞,固有名詞,地域,一般,*,*,九州,キュウシュウ,キューシュー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 6 9D 3/4 1.968550
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# * 7 9D 1/2 3.101574
# ↓	記号,一般,*,*,*,*,↓,↓,↓
# 和歌山	名詞,固有名詞,地域,一般,*,*,和歌山,ワカヤマ,ワカヤマ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 8 9D 0/1 3.106002
# 土砂ダム	名詞,固有名詞,一般,*,*,*,土砂ダム,ドシャダム,ドシャダム
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 9 12D 1/2 1.779384
# くずれ	動詞,自立,*,*,一段,連用形,くずれる,クズレ,クズレ
# そう	名詞,接尾,助動詞語幹,*,*,*,そう,ソウ,ソー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# * 10 12D 4/5 2.217075
# 危険	名詞,形容動詞語幹,*,*,*,*,危険,キケン,キケン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# ↓	記号,一般,*,*,*,*,↓,↓,↓
# 名古屋	名詞,固有名詞,地域,一般,*,*,名古屋,ナゴヤ,ナゴヤ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 11 12D 0/2 2.008721
# 1万人	名詞,固有名詞,一般,*,*,*,1万人,イチマンニン,イチマンニン
# ほど	助詞,副助詞,*,*,*,*,ほど,ホド,ホド
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 12 15D 1/2 1.457572
# 避難	名詞,サ変接続,*,*,*,*,避難,ヒナン,ヒナン
# 対象	名詞,一般,*,*,*,*,対象,タイショウ,タイショー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# * 13 14D 0/1 0.914780
# 風	名詞,一般,*,*,*,*,風,カゼ,カゼ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# * 14 15D 0/1 2.955988
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 15 67D 0/1 1.346784
# 強い	形容詞,自立,*,*,形容詞・アウオ段,基本形,強い,ツヨイ,ツヨイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# * 16 17D 1/2 1.546211
# ↓	記号,一般,*,*,*,*,↓,↓,↓
# 全国	名詞,一般,*,*,*,*,全国,ゼンコク,ゼンコク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 17 20D 3/4 1.494753
# 皆さん	名詞,一般,*,*,*,*,皆さん,ミナサン,ミナサン
# ！	記号,一般,*,*,*,*,！,！,！
# 今	接頭詞,名詞接続,*,*,*,*,今,コン,コン
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 18 20D 5/6 2.296603
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# ほら	感動詞,*,*,*,*,*,ほら,ホラ,ホラ
# ！	記号,一般,*,*,*,*,！,！,！
# 新宿駅	名詞,固有名詞,地域,一般,*,*,新宿駅,シンジュクエキ,シンジュクエキ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 19 20D 0/1 2.540451
# みんな	名詞,代名詞,一般,*,*,*,みんな,ミンナ,ミンナ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 20 25D 0/2 0.779572
# 困っ	動詞,自立,*,*,五段・ラ行,連用タ接続,困る,コマッ,コマッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# ！	記号,一般,*,*,*,*,！,！,！
# * 21 23D 0/1 0.047196
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 22 23D 0/0 1.529456
# すごく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,すごい,スゴク,スゴク
# * 23 25D 0/1 1.565882
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 24 25D 1/2 1.077054
# ！	記号,一般,*,*,*,*,！,！,！
# 全国	名詞,一般,*,*,*,*,全国,ゼンコク,ゼンコク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 25 26D 4/6 0.711392
# 皆	名詞,代名詞,一般,*,*,*,皆,ミナ,ミナ
# さ～	副詞,一般,*,*,*,*,さー,サー,サー
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# ！	記号,一般,*,*,*,*,！,！,！
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 26 27D 8/9 0.678354
# 思い	動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# ！	記号,一般,*,*,*,*,！,！,！
# 東京人	名詞,固有名詞,一般,*,*,*,東京人,トウキョウジン,トーキョージン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 27 28D 1/2 0.242349
# 今	接頭詞,名詞接続,*,*,*,*,今,コン,コン
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 28 29D 1/2 0.172159
# ！	記号,一般,*,*,*,*,！,！,！
# 池袋	名詞,固有名詞,地域,一般,*,*,池袋,イケブクロ,イケブクロ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 29 30D 0/1 0.431044
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 30 35D 0/0 0.531698
# よ～	形容詞,自立,*,*,形容詞・アウオ段,ガル接続,よい,ヨー,ヨー
# ！	記号,一般,*,*,*,*,！,！,！
# ！	記号,一般,*,*,*,*,！,！,！
# * 31 35D 0/1 0.967151
# ついで	名詞,一般,*,*,*,*,ついで,ツイデ,ツイデ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 32 35D 0/1 0.762801
# 横浜	名詞,固有名詞,地域,一般,*,*,横浜,ヨコハマ,ヨコハマ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 33 35D 3/4 1.217481
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# 風	名詞,一般,*,*,*,*,風,カゼ,カゼ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 34 35D 4/5 1.878932
# 強い	形容詞,自立,*,*,形容詞・アウオ段,基本形,強い,ツヨイ,ツヨイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# 首都	名詞,一般,*,*,*,*,首都,シュト,シュト
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 35 38D 0/1 1.264026
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# ！	記号,一般,*,*,*,*,！,！,！
# * 36 38D 0/1 2.536576
# 水たまり	名詞,一般,*,*,*,*,水たまり,ミズタマリ,ミズタマリ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 37 38D 0/1 2.307851
# あちこち	名詞,代名詞,一般,*,*,*,あちこち,アチコチ,アチコチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 38 67D 8/9 2.323660
# 出来	動詞,自立,*,*,一段,連用形,出来る,デキ,デキ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# ！	記号,一般,*,*,*,*,！,！,！
# ！	記号,一般,*,*,*,*,！,！,！
# あ	感動詞,*,*,*,*,*,あ,ア,ア
# ～	記号,一般,*,*,*,*,*
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# ！	記号,一般,*,*,*,*,！,！,！
# * 39 41D 1/2 0.333026
# 日本の首都	名詞,固有名詞,一般,*,*,*,日本の首都,ニッポンノシュト,ニッポンノシュト
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 40 41D 0/0 1.567909
# すごく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,すごい,スゴク,スゴク
# * 41 43D 0/1 0.635812
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 42 43D 0/0 0.814813
# ！	記号,一般,*,*,*,*,！,！,！
# * 43 67D 0/1 1.344768
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ！	記号,一般,*,*,*,*,！,！,！
# * 44 47D 0/1 0.902497
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 45 46D 0/0 1.102666
# すごく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,すごい,スゴク,スゴク
# * 46 47D 0/1 1.618987
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 47 67D 0/1 1.805922
# 状況	名詞,一般,*,*,*,*,状況,ジョウキョウ,ジョーキョー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# * 48 67D 0/1 0.373038
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 49 50D 0/1 0.125472
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# * 50 56D 0/0 0.193505
# ！	記号,一般,*,*,*,*,！,！,！
# * 51 56D 0/0 2.118603
# どう	副詞,助詞類接続,*,*,*,*,どう,ドウ,ドー
# * 52 56D 0/1 1.431323
# しよう	名詞,一般,*,*,*,*,しよう,シヨウ,シヨー
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 53 56D 5/6 2.373721
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# 大都市	名詞,一般,*,*,*,*,大都市,ダイトシ,ダイトシ
# 首都	名詞,一般,*,*,*,*,首都,シュト,シュト
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 54 55D 3/3 0.025856
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# みなさん	名詞,代名詞,一般,*,*,*,みなさん,ミナサン,ミナサン
# * 55 56D 0/1 2.992755
# 気	名詞,一般,*,*,*,*,気,キ,キ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 56 67D 0/2 2.116053
# つけ	動詞,自立,*,*,一段,連用形,つける,ツケ,ツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ください	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,くださる,クダサイ,クダサイ
# ！	記号,一般,*,*,*,*,！,！,！
# ！	記号,一般,*,*,*,*,！,！,！
# * 57 59D 3/4 0.445432
# ああ	感動詞,*,*,*,*,*,ああ,アア,アー
# ～	記号,一般,*,*,*,*,*
# 日本の首都	名詞,固有名詞,一般,*,*,*,日本の首都,ニッポンノシュト,ニッポンノシュト
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 58 59D 0/1 0.814625
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 59 63D 0/1 1.330742
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# * 60 63D 1/1 0.582498
# ！	記号,一般,*,*,*,*,！,！,！
# みなさん	名詞,代名詞,一般,*,*,*,みなさん,ミナサン,ミナサン
# ！	記号,一般,*,*,*,*,！,！,！
# * 61 63D 0/1 1.088988
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 62 63D 0/1 1.117948
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 63 67D 4/4 2.211958
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ！	記号,一般,*,*,*,*,！,！,！
# ほら	感動詞,*,*,*,*,*,ほら,ホラ,ホラ
# ！	記号,一般,*,*,*,*,！,！,！
# ！	記号,一般,*,*,*,*,！,！,！
# ↓	記号,一般,*,*,*,*,↓,↓,↓
# * 64 67D 0/1 1.823073
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 65 67D 0/1 2.413919
# 東北	名詞,一般,*,*,*,*,東北,トウホク,トーホク
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 66 67D 0/1 2.206159
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 67 68D 0/1 1.346784
# 大変	名詞,形容動詞語幹,*,*,*,*,大変,タイヘン,タイヘン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# * 68 -1D 0/1 0.000000
# がんばっ	動詞,自立,*,*,五段・ラ行,連用タ接続,がんばる,ガンバッ,ガンバッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# EOS
#
# * 0 3D 0/1 0.681636
# 予測	名詞,サ変接続,*,*,*,*,予測,ヨソク,ヨソク
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 1 2D 0/1 1.834721
# 技術	名詞,一般,*,*,*,*,技術,ギジュツ,ギジュツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 2 3D 0/1 2.436390
# 進歩	名詞,サ変接続,*,*,*,*,進歩,シンポ,シンポ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 3 7D 4/8 -0.675512
# 早く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク
# ・	記号,一般,*,*,*,*,・,・,・
# 正確	名詞,形容動詞語幹,*,*,*,*,正確,セイカク,セイカク
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 来	動詞,非自立,*,*,カ変・来ル,連用形,来る,キ,キ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# * 4 6D 0/1 1.505089
# 対応	名詞,サ変接続,*,*,*,*,対応,タイオウ,タイオー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 5 6D 1/2 1.747507
# いつまでも	名詞,固有名詞,一般,*,*,*,いつまでも,イツマデモ,イツマデモ
# 旧式	名詞,一般,*,*,*,*,旧式,キュウシキ,キューシキ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 6 7D 4/5 -0.675512
# 生かし	動詞,自立,*,*,五段・サ行,連用形,生かす,イカシ,イカシ
# きれ	動詞,非自立,*,*,一段,未然形,きれる,キレ,キレ
# て	動詞,非自立,*,*,一段,未然形,てる,テ,テ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 7 -1D 0/0 0.000000
# 残念	名詞,形容動詞語幹,*,*,*,*,残念,ザンネン,ザンネン
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# EOS
#
# * 0 3D 0/1 -1.397109
# 横浜	名詞,固有名詞,地域,一般,*,*,横浜,ヨコハマ,ヨコハマ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# * 1 2D 0/0 0.138790
# いま	名詞,副詞可能,*,*,*,*,いま,イマ,イマ
# * 2 3D 3/3 -1.397109
# 止ん	動詞,自立,*,*,五段・マ行,連用タ接続,止む,ヤン,ヤン
# でる	動詞,非自立,*,*,一段,基本形,でる,デル,デル
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# また	接続詞,*,*,*,*,*,また,マタ,マタ
# * 3 -1D 1/3 0.000000
# 降り出す	動詞,自立,*,*,五段・サ行,基本形,降り出す,フリダス,フリダス
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 2.121734
# 田舎	名詞,一般,*,*,*,*,田舎,イナカ,イナカ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 4D 2/3 -2.280608
# 爺	名詞,一般,*,*,*,*,爺,ジイ,ジー
# ちゃん	名詞,接尾,人名,*,*,*,ちゃん,チャン,チャン
# 婆ちゃん	名詞,一般,*,*,*,*,婆ちゃん,バアチャン,バーチャン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 2 3D 1/2 4.317084
# 「	記号,括弧開,*,*,*,*,「,「,「
# 用水路	名詞,一般,*,*,*,*,用水路,ヨウスイロ,ヨースイロ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 3 4D 0/1 -2.280608
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 」	記号,括弧閉,*,*,*,*,」,」,」
# * 4 -1D 2/4 0.000000
# 行か	動詞,自立,*,*,五段・カ行促音便,未然形,行く,イカ,イカ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 1.858804
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 2D 0/1 1.808900
# 切り上げ	名詞,サ変接続,*,*,*,*,切り上げ,キリアゲ,キリアゲ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 2 9D 0/0 1.417882
# 大切	名詞,形容動詞語幹,*,*,*,*,大切,タイセツ,タイセツ
# 。	記号,句点,*,*,*,*,。,。,。
# * 3 9D 0/1 1.741910
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 4 5D 0/1 1.501047
# 過剰	名詞,形容動詞語幹,*,*,*,*,過剰,カジョウ,カジョー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 5 7D 0/0 0.580734
# くらい	助詞,副助詞,*,*,*,*,くらい,クライ,クライ
# * 6 7D 0/1 1.475301
# 臆病	名詞,形容動詞語幹,*,*,*,*,臆病,オクビョウ,オクビョー
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# * 7 9D 1/2 1.989479
# 心配	名詞,サ変接続,*,*,*,*,心配,シンパイ,シンパイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 8 9D 0/0 2.331793
# ちょうど	副詞,一般,*,*,*,*,ちょうど,チョウド,チョード
# * 9 13D 0/0 0.558341
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# 。	記号,句点,*,*,*,*,。,。,。
# * 10 13D 0/1 2.704367
# コロナ	名詞,一般,*,*,*,*,コロナ,コロナ,コロナ
# より	助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# * 11 12D 0/1 2.659975
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 12 13D 0/1 2.054413
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 13 24D 0/0 1.863147
# 怖い	形容詞,自立,*,*,形容詞・アウオ段,基本形,怖い,コワイ,コワイ
# 。	記号,句点,*,*,*,*,。,。,。
# * 14 15D 0/0 1.763948
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# * 15 19D 0/1 0.651342
# 降る	動詞,自立,*,*,五段・ラ行,基本形,降る,フル,フル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# * 16 17D 0/0 0.416618
# ほんと	感動詞,*,*,*,*,*,ほんと,ホント,ホント
# * 17 19D 1/4 1.333628
# 運転	名詞,サ変接続,*,*,*,*,運転,ウンテン,ウンテン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	動詞,非自立,*,*,一段,連用形,てる,テ,テ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 18 19D 0/1 2.109661
# 視界	名詞,一般,*,*,*,*,視界,シカイ,シカイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 19 24D 0/2 2.761083
# 見え	動詞,自立,*,*,一段,未然形,見える,ミエ,ミエ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# * 20 21D 0/0 2.061826
# そんな	連体詞,*,*,*,*,*,そんな,ソンナ,ソンナ
# * 21 24D 0/1 1.836984
# 時	名詞,非自立,副詞可能,*,*,*,時,トキ,トキ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 22 24D 0/1 4.042341
# 運転	名詞,サ変接続,*,*,*,*,運転,ウンテン,ウンテン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 23 24D 0/0 3.103688
# 一時	名詞,副詞可能,*,*,*,*,一時,イチジ,イチジ
# * 24 26D 1/1 0.871156
# 中断	名詞,サ変接続,*,*,*,*,中断,チュウダン,チューダン
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 。	記号,句点,*,*,*,*,。,。,。
# * 25 26D 0/1 3.396758
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 26 33D 0/1 0.883749
# 心がけ	動詞,自立,*,*,一段,連用形,心がける,ココロガケ,ココロガケ
# てる	動詞,非自立,*,*,一段,基本形,てる,テル,テル
# 。	記号,句点,*,*,*,*,。,。,。
# * 27 28D 0/1 1.174614
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 28 30D 0/2 1.608427
# はねる	動詞,自立,*,*,一段,基本形,はねる,ハネル,ハネル
# より	助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 29 30D 0/1 1.936141
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 30 31D 0/0 1.965468
# 遅れる	動詞,自立,*,*,一段,基本形,遅れる,オクレル,オクレル
# * 31 33D 0/1 1.923649
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 32 33D 3/4 1.642576
# １	名詞,数,*,*,*,*,１,イチ,イチ
# ０	名詞,数,*,*,*,*,０,ゼロ,ゼロ
# ０	名詞,数,*,*,*,*,０,ゼロ,ゼロ
# 倍	名詞,接尾,助数詞,*,*,*,倍,バイ,バイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 33 40D 0/2 -1.603435
# マシ	名詞,形容動詞語幹,*,*,*,*,まし,マシ,マシ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# 。	記号,句点,*,*,*,*,。,。,。
# * 34 35D 0/1 1.896152
# 歩行者	名詞,固有名詞,一般,*,*,*,歩行者,ホコウシャ,ホコーシャ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 35 37D 0/1 0.778637
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 36 37D 0/2 1.573216
# 車	名詞,一般,*,*,*,*,車,クルマ,クルマ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 37 38D 0/4 1.522809
# 見え	動詞,自立,*,*,一段,連用形,見える,ミエ,ミエ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,未然形,いる,イ,イ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 38 40D 0/1 -1.603435
# 思っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,思う,オモッ,オモッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 39 40D 0/1 -1.603435
# 気	名詞,一般,*,*,*,*,気,キ,キ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 40 -1D 0/1 0.000000
# つけ	動詞,自立,*,*,一段,連用形,つける,ツケ,ツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 1/2 4.010008
# 「	記号,括弧開,*,*,*,*,「,「,「
# 天気	名詞,一般,*,*,*,*,天気,テンキ,テンキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 2D 3/4 1.510263
# 裂け目	名詞,一般,*,*,*,*,裂け目,サケメ,サケメ
# 」	記号,括弧閉,*,*,*,*,」,」,」
# 地域	名詞,一般,*,*,*,*,地域,チイキ,チイキ
# 住み	動詞,自立,*,*,五段・マ行,連用形,住む,スミ,スミ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 2 4D 0/1 0.939908
# 者	名詞,非自立,一般,*,*,*,者,モノ,モノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 3 4D 0/0 1.811252
# ほんの	連体詞,*,*,*,*,*,ほんの,ホンノ,ホンノ
# * 4 5D 2/3 1.062307
# 数	名詞,数,*,*,*,*,数,スウ,スー
# キロ	名詞,接尾,助数詞,*,*,*,キロ,キロ,キロ
# 東西	名詞,一般,*,*,*,*,東西,トウザイ,トーザイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 5 7D 1/2 1.439744
# 移動	名詞,サ変接続,*,*,*,*,移動,イドウ,イドー
# すれ	動詞,自立,*,*,サ変・スル,仮定形,する,スレ,スレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# * 6 7D 0/1 2.810113
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 7 46D 0/3 0.063613
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# * 8 9D 0/1 1.450855
# 私	名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 9 46D 1/2 0.788312
# 住居	名詞,一般,*,*,*,*,住居,ジュウキョ,ジューキョ
# 区域	名詞,一般,*,*,*,*,区域,クイキ,クイキ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 10 13D 0/2 0.795221
# 降り	動詞,自立,*,*,一段,連用形,降りる,オリ,オリ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# * 11 12D 0/0 1.000554
# せいぜい	副詞,助詞類接続,*,*,*,*,せいぜい,セイゼイ,セイゼイ
# * 12 13D 0/1 0.849990
# 曇り	動詞,自立,*,*,五段・ラ行,連用形,曇る,クモリ,クモリ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 13 14D 0/1 1.571611
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 14 26D 1/2 0.270815
# 降る	動詞,自立,*,*,五段・ラ行,基本形,降る,フル,フル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 15 18D 0/1 0.978121
# 主	名詞,形容動詞語幹,*,*,*,*,主,オモ,オモ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# * 16 18D 0/1 0.780671
# 夜	名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 17 18D 0/2 0.186720
# 朝	名詞,副詞可能,*,*,*,*,朝,アサ,アサ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 18 19D 0/1 0.533201
# 止み	動詞,自立,*,*,五段・マ行,連用形,止む,ヤミ,ヤミ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# * 19 26D 0/1 0.026894
# 台風	名詞,一般,*,*,*,*,台風,タイフウ,タイフー
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 20 21D 0/1 0.245220
# 強め	動詞,自立,*,*,一段,連用形,強める,ツヨメ,ツヨメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 21 22D 0/1 0.148834
# 風	名詞,一般,*,*,*,*,風,カゼ,カゼ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# * 22 25D 1/2 0.630149
# 通常	名詞,一般,*,*,*,*,通常,ツウジョウ,ツージョー
# 雨	名詞,接尾,一般,*,*,*,雨,ウ,ウ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 23 24D 0/1 1.644979
# 水	名詞,一般,*,*,*,*,水,ミズ,ミズ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 24 25D 0/1 0.837518
# 被害	名詞,一般,*,*,*,*,被害,ヒガイ,ヒガイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 25 26D 0/2 1.235833
# 出	動詞,自立,*,*,一段,連用形,出る,デ,デ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# * 26 27D 0/1 0.282480
# 水害	名詞,一般,*,*,*,*,水害,スイガイ,スイガイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 27 29D 0/1 0.891232
# いう	動詞,自立,*,*,五段・ワ行促音便,基本形,いう,イウ,イウ
# より	助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# * 28 29D 0/1 1.749494
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 29 32D 0/3 1.418310
# 降ら	動詞,自立,*,*,五段・ラ行,未然形,降る,フラ,フラ
# な	助動詞,*,*,*,特殊・ナイ,ガル接続,ない,ナ,ナ
# すぎ	動詞,非自立,*,*,一段,連用形,すぎる,スギ,スギ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 30 32D 0/0 1.157176
# いざ	副詞,一般,*,*,*,*,いざ,イザ,イザ
# * 31 32D 0/1 1.858145
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 32 33D 0/1 1.460249
# 来	動詞,自立,*,*,カ変・来ル,連用形,来る,キ,キ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 33 34D 0/1 1.075041
# 際	名詞,非自立,副詞可能,*,*,*,際,サイ,サイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 34 37D 1/2 0.800991
# 土砂災害	名詞,固有名詞,一般,*,*,*,土砂災害,ドシャサイガイ,ドシャサイガイ
# 地盤	名詞,一般,*,*,*,*,地盤,ジバン,ジバン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 35 37D 0/1 1.668921
# 非常	名詞,形容動詞語幹,*,*,*,*,非常,ヒジョウ,ヒジョー
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# * 36 37D 0/1 1.299955
# 乾燥	名詞,サ変接続,*,*,*,*,乾燥,カンソウ,カンソー
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# * 37 39D 1/3 0.778306
# 硬化	名詞,サ変接続,*,*,*,*,硬化,コウカ,コーカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# * 38 39D 0/1 1.416450
# まとも	名詞,形容動詞語幹,*,*,*,*,まとも,マトモ,マトモ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 39 46D 0/1 1.321214
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 40 41D 0/0 1.589468
# ここ	名詞,代名詞,一般,*,*,*,ここ,ココ,ココ
# * 41 43D 1/2 0.382369
# １	名詞,数,*,*,*,*,１,イチ,イチ
# か月	名詞,接尾,助数詞,*,*,*,か月,カゲツ,カゲツ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 42 43D 1/2 1.215505
# ７	名詞,数,*,*,*,*,７,ナナ,ナナ
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 43 45D 0/1 1.076190
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 44 45D 0/0 1.245181
# こういう	連体詞,*,*,*,*,*,こういう,コウイウ,コーユウ
# * 45 46D 1/3 2.082305
# 地域	名詞,一般,*,*,*,*,地域,チイキ,チイキ
# 全国的	名詞,固有名詞,一般,*,*,*,全国的,ゼンコクテキ,ゼンコクテキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 46 57D 1/3 -1.114641
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# そう	名詞,接尾,助動詞語幹,*,*,*,そう,ソウ,ソー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# * 47 48D 2/4 2.452956
# 被害	名詞,一般,*,*,*,*,被害,ヒガイ,ヒガイ
# 過多	名詞,一般,*,*,*,*,過多,カタ,カタ
# 地域	名詞,一般,*,*,*,*,地域,チイキ,チイキ
# へ	助詞,格助詞,一般,*,*,*,へ,ヘ,エ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 48 57D 2/3 -1.114641
# 配慮	名詞,サ変接続,*,*,*,*,配慮,ハイリョ,ハイリョ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# * 49 52D 0/0 1.175118
# あまり	副詞,助詞類接続,*,*,*,*,あまり,アマリ,アマリ
# * 50 51D 0/1 1.683242
# ニュース	名詞,一般,*,*,*,*,ニュース,ニュース,ニュース
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# * 51 52D 0/1 0.996609
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 52 57D 0/3 -1.114641
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# * 53 54D 0/0 0.663577
# 本当に	副詞,一般,*,*,*,*,本当に,ホントウニ,ホントーニ
# * 54 55D 0/1 1.153094
# 不思議	名詞,形容動詞語幹,*,*,*,*,不思議,フシギ,フシギ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 55 56D 0/1 1.918712
# 天気	名詞,一般,*,*,*,*,天気,テンキ,テンキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 56 57D 0/1 -1.114641
# 裂け目	名詞,一般,*,*,*,*,裂け目,サケメ,サケメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 57 -1D 0/1 0.000000
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# EOS
#
# * 0 3D 0/1 -1.421279
# 天罰	名詞,一般,*,*,*,*,天罰,テンバツ,テンバツ
# じゃ	助詞,副助詞,*,*,*,*,じゃ,ジャ,ジャ
# ！	記号,一般,*,*,*,*,！,！,！
# * 1 3D 0/1 -1.421279
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 2 3D 0/1 -1.421279
# 天罰	名詞,一般,*,*,*,*,天罰,テンバツ,テンバツ
# じゃあ	助詞,副助詞,*,*,*,*,じゃあ,ジャア,ジャー
# * 3 -1D 0/0 0.000000
# ～！	記号,一般,*,*,*,*,*
# EOS
#
# * 0 2D 0/0 0.699499
# どうせ	副詞,一般,*,*,*,*,どうせ,ドウセ,ドーセ
# * 1 2D 1/1 1.954948
# 二	名詞,数,*,*,*,*,二,ニ,ニ
# 日間	名詞,接尾,助数詞,*,*,*,日間,ニチカン,ニチカン
# * 2 13D 1/2 -0.160942
# 降り続く	動詞,自立,*,*,五段・カ行イ音便,基本形,降り続く,フリツヅク,フリツズク
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# なら	助動詞,*,*,*,特殊・ダ,仮定形,だ,ナラ,ナラ
# 、	記号,読点,*,*,*,*,、,、,、
# * 3 4D 0/1 1.578752
# 全国	名詞,一般,*,*,*,*,全国,ゼンコク,ゼンコク
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 4 5D 1/3 0.611838
# 蔓延	名詞,サ変接続,*,*,*,*,蔓延,マンエン,マンエン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# * 5 6D 0/1 0.511003
# 厄介者	名詞,固有名詞,一般,*,*,*,厄介者,ヤッカイモノ,ヤッカイモノ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 6 7D 1/1 1.393790
# コロナウイルス	名詞,固有名詞,一般,*,*,*,コロナウイルス,コロナウイルス,コロナウイルス
# 全部	名詞,副詞可能,*,*,*,*,全部,ゼンブ,ゼンブ
# * 7 8D 0/0 1.608321
# 洗い流し	動詞,自立,*,*,五段・サ行,連用形,洗い流す,アライナガシ,アライナガシ
# * 8 9D 1/3 0.453634
# 浄化	名詞,サ変接続,*,*,*,*,浄化,ジョウカ,ジョーカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれ	動詞,非自立,*,*,一段・クレル,連用形,くれる,クレ,クレ
# * 9 12D 0/0 0.597497
# よぉ	形容詞,自立,*,*,形容詞・アウオ段,ガル接続,よい,ヨー,ヨー
# ！	記号,一般,*,*,*,*,！,！,！
# * 10 11D 1/1 2.028007
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# 位	名詞,接尾,助数詞,*,*,*,位,イ,イ
# * 11 12D 0/1 0.021542
# 出来る	動詞,自立,*,*,一段,基本形,出来る,デキル,デキル
# だろ	助動詞,*,*,*,特殊・ダ,未然形,だ,ダロ,ダロ
# 、	記号,読点,*,*,*,*,、,、,、
# * 12 13D 2/4 -0.160942
# ゲリラ豪雨	名詞,固有名詞,一般,*,*,*,ゲリラ豪雨,ゲリラゴウウ,ゲリラゴウー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# * 13 -1D 1/1 0.000000
# (	記号,一般,*,*,*,*,*
# 怒	動詞,自立,*,*,五段・ラ行,体言接続特殊２,怒る,イカ,イカ
# )	記号,一般,*,*,*,*,*
# EOS
#
# * 0 1D 1/2 1.643021
# 近畿地方	名詞,固有名詞,一般,*,*,*,近畿地方,キンキチホウ,キンキチホー
# 中部	名詞,一般,*,*,*,*,中部,チュウブ,チューブ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 1 17D 3/4 -0.292080
# 太平洋側	名詞,固有名詞,一般,*,*,*,太平洋側,タイヘイヨウガワ,タイヘイヨーガワ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# * 2 9D 0/1 0.089506
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 3 5D 1/3 0.171919
# 小康	名詞,一般,*,*,*,*,小康,ショウコウ,ショーコー
# 状態	名詞,一般,*,*,*,*,状態,ジョウタイ,ジョータイ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# * 4 5D 0/0 0.855417
# つい	副詞,一般,*,*,*,*,つい,ツイ,ツイ
# * 5 9D 0/1 0.617289
# さっき	名詞,副詞可能,*,*,*,*,さっき,サッキ,サッキ
# まで	助詞,副助詞,*,*,*,*,まで,マデ,マデ
# * 6 7D 0/2 0.624592
# ヤバい	名詞,固有名詞,一般,*,*,*,ヤバい,ヤバイ,ヤバイ
# くらい	助詞,副助詞,*,*,*,*,くらい,クライ,クライ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 7 9D 0/1 2.514394
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# * 8 9D 0/1 2.095814
# 時折	名詞,副詞可能,*,*,*,*,時折,トキオリ,トキオリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 9 17D 0/0 -0.292080
# 突風	名詞,一般,*,*,*,*,突風,トップウ,トップー
# 。	記号,句点,*,*,*,*,。,。,。
# * 10 11D 0/1 1.547255
# 太平洋側	名詞,固有名詞,一般,*,*,*,太平洋側,タイヘイヨウガワ,タイヘイヨーガワ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# * 11 12D 1/2 2.042081
# 線上	名詞,一般,*,*,*,*,線上,センジョウ,センジョー
# 降水帯	名詞,固有名詞,一般,*,*,*,降水帯,コウスイタイ,コースイタイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 12 13D 0/2 1.824593
# 出来	動詞,自立,*,*,一段,連用形,出来る,デキ,デキ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# * 13 17D 0/1 -0.292080
# 伊豆半島	名詞,固有名詞,一般,*,*,*,伊豆半島,イズハントウ,イズハントー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 14 15D 0/2 1.224921
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# より	助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 15 17D 3/4 -0.292080
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# わけ	名詞,非自立,一般,*,*,*,わけ,ワケ,ワケ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# * 16 17D 1/2 -0.292080
# …。	名詞,固有名詞,人名,一般,*,*,…。,サイレンス,サイレンス
# 怖い	形容詞,自立,*,*,形容詞・アウオ段,基本形,怖い,コワイ,コワイ
# くらい	助詞,副助詞,*,*,*,*,くらい,クライ,クライ
# * 17 -1D 0/2 0.000000
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# てる	動詞,非自立,*,*,一段,基本形,てる,テル,テル
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 5D 0/1 2.967457
# 去年	名詞,副詞可能,*,*,*,*,去年,キョネン,キョネン
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 1 2D 0/0 1.145507
# ７月	名詞,副詞可能,*,*,*,*,7月,シチガツ,シチガツ
# * 2 5D 0/1 3.577126
# 入っ	動詞,自立,*,*,五段・ラ行,連用タ接続,入る,ハイッ,ハイッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 3 5D 0/1 3.647551
# すぐ	副詞,助詞類接続,*,*,*,*,すぐ,スグ,スグ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# * 4 5D 0/1 4.245695
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 5 11D 0/2 -2.446531
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# * 6 8D 0/1 1.014099
# 今年	名詞,副詞可能,*,*,*,*,今年,コトシ,コトシ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 7 8D 0/1 2.895641
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 8 11D 0/1 -2.446531
# 少ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,少ない,スクナイ,スクナイ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# 、	記号,読点,*,*,*,*,、,、,、
# * 9 10D 0/2 1.908772
# 日頃	名詞,副詞可能,*,*,*,*,日頃,ヒゴロ,ヒゴロ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 10 11D 0/1 -2.446531
# 準備	名詞,サ変接続,*,*,*,*,準備,ジュンビ,ジュンビ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 11 -1D 0/1 0.000000
# 重要	名詞,形容動詞語幹,*,*,*,*,重要,ジュウヨウ,ジューヨー
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/2 0.499192
# 着	動詞,自立,*,*,一段,連用形,着る,キ,キ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いく	動詞,非自立,*,*,五段・カ行促音便,基本形,いく,イク,イク
# * 1 2D 0/1 0.073976
# 服	名詞,一般,*,*,*,*,服,フク,フク
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# * 2 3D 0/1 0.073976
# 靴	名詞,一般,*,*,*,*,靴,クツ,クツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 3 -1D 0/0 0.000000
# 悩む	動詞,自立,*,*,五段・マ行,基本形,悩む,ナヤム,ナヤム
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 8D 0/0 -0.275004
# とう	副詞,助詞類接続,*,*,*,*,とう,トウ,トウ
# * 1 2D 1/1 0.049359
# きょうは	名詞,一般,*,*,*,*,教派,キョウハ,キョーハ
# ーー	名詞,一般,*,*,*,*,*
# 、	記号,読点,*,*,*,*,、,、,、
# 、	記号,読点,*,*,*,*,、,、,、
# * 2 8D 1/2 -0.275004
# 雨降り	名詞,一般,*,*,*,*,雨降り,アメフリ,アメフリ
# ーーー	名詞,一般,*,*,*,*,*
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 3 4D 0/0 0.247202
# ぜーー	副詞,一般,*,*,*,*,ぜー,ゼーー,ゼー
# * 4 6D 0/0 1.094800
# 儚く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,儚い,ハカナク,ハカナク
# * 5 6D 0/1 1.737958
# 過去	名詞,副詞可能,*,*,*,*,過去,カコ,カコ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 6 8D 0/0 -0.275004
# ぬら	動詞,自立,*,*,五段・ラ行,未然形,ぬる,ヌラ,ヌラ
# * 7 8D 0/0 -0.275004
# すぅー	副詞,一般,*,*,*,*,すー,スー,スー
# 、	記号,読点,*,*,*,*,、,、,、
# * 8 -1D 0/0 0.000000
# ！	記号,一般,*,*,*,*,！,！,！
# 、	記号,読点,*,*,*,*,、,、,、
# 、	記号,読点,*,*,*,*,、,、,、
# EOS
#
# * 0 1D 0/1 0.421093
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 1 2D 1/3 0.421093
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# 流	名詞,接尾,一般,*,*,*,流,リュウ,リュー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ど	助詞,接続助詞,*,*,*,*,ど,ド,ド
# * 2 -1D 0/0 0.000000
# しゃーっ	副詞,一般,*,*,*,*,しゃーっ,シャーッ,シャーッ
# EOS
#
# * 0 1D 0/1 1.923942
# 梅雨	名詞,一般,*,*,*,*,梅雨,ツユ,ツユ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 3D 0/2 2.024971
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 2 3D 0/1 1.803831
# 最近	名詞,副詞可能,*,*,*,*,最近,サイキン,サイキン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 3 17D 1/3 -1.017380
# 油断	名詞,サ変接続,*,*,*,*,油断,ユダン,ユダン
# 出来	動詞,自立,*,*,一段,未然形,出来る,デキ,デキ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# 。	記号,句点,*,*,*,*,。,。,。
# * 4 5D 1/2 2.501352
# 台風	名詞,一般,*,*,*,*,台風,タイフウ,タイフー
# 並	名詞,一般,*,*,*,*,並,ナミ,ナミ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 5 6D 0/1 1.646188
# 風雨	名詞,一般,*,*,*,*,風雨,フウウ,フーウ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 6 17D 1/2 -1.017380
# 想定	名詞,サ変接続,*,*,*,*,想定,ソウテイ,ソーテイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 7 10D 0/1 0.293277
# 住まい	名詞,一般,*,*,*,*,住まい,スマイ,スマイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 8 9D 0/1 1.324087
# 補強	名詞,サ変接続,*,*,*,*,補強,ホキョウ,ホキョー
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# * 9 10D 0/0 0.578538
# 戸締まり	名詞,一般,*,*,*,*,戸締まり,トジマリ,トジマリ
# 、	記号,読点,*,*,*,*,、,、,、
# * 10 12D 0/1 0.982007
# 食料	名詞,一般,*,*,*,*,食料,ショクリョウ,ショクリョー
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# * 11 12D 1/2 1.352897
# 防災	名詞,サ変接続,*,*,*,*,防災,ボウサイ,ボーサイ
# 品	名詞,接尾,一般,*,*,*,品,ヒン,ヒン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 12 14D 0/0 0.619743
# 備蓄	名詞,サ変接続,*,*,*,*,備蓄,ビチク,ビチク
# 、	記号,読点,*,*,*,*,、,、,、
# * 13 14D 0/1 2.226086
# 避難所	名詞,固有名詞,地域,一般,*,*,避難所,ヒナンジョ,ヒナンジョ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 14 17D 1/2 -1.017380
# 確認	名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# 等	名詞,接尾,一般,*,*,*,等,トウ,トー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 15 17D 0/1 -1.017380
# やっ	動詞,自立,*,*,五段・ラ行,連用タ接続,やる,ヤッ,ヤッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 16 17D 0/1 -1.017380
# た方	名詞,一般,*,*,*,*,他方,タホウ,タホー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 17 -1D 0/2 0.000000
# 良い	形容詞,自立,*,*,形容詞・アウオ段,基本形,良い,ヨイ,ヨイ
# だろ	助動詞,*,*,*,特殊・ダ,未然形,だ,ダロ,ダロ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/0 1.384589
# 昨年	名詞,副詞可能,*,*,*,*,昨年,サクネン,サクネン
# * 1 3D 0/0 0.193302
# ７月	名詞,副詞可能,*,*,*,*,7月,シチガツ,シチガツ
# 、	記号,読点,*,*,*,*,、,、,、
# * 2 3D 0/1 1.840175
# 関東	名詞,固有名詞,地域,一般,*,*,関東,カントウ,カントー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 3 4D 1/2 1.422682
# 発生	名詞,サ変接続,*,*,*,*,発生,ハッセイ,ハッセイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 4 6D 0/1 0.731623
# 線状降水帯	名詞,固有名詞,一般,*,*,*,線状降水帯,センジョウコウスイタイ,センジョーコースイタイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 5 6D 3/4 1.812382
# 出くわし	動詞,自立,*,*,五段・サ行,連用形,出くわす,デクワシ,デクワシ
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# 愛車	名詞,一般,*,*,*,*,愛車,アイシャ,アイシャ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 6 7D 1/3 1.186384
# 水没	名詞,サ変接続,*,*,*,*,水没,スイボツ,スイボツ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# せ	動詞,接尾,*,*,一段,連用形,せる,セ,セ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 7 8D 0/1 2.432760
# 悪夢	名詞,一般,*,*,*,*,悪夢,アクム,アクム
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 8 10D 0/0 0.269076
# 思い出す	動詞,自立,*,*,五段・サ行,基本形,思い出す,オモイダス,オモイダス
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# 　	記号,空白,*,*,*,*,　,　,
# * 9 10D 1/2 1.093918
# 瞬間	名詞,副詞可能,*,*,*,*,瞬間,シュンカン,シュンカン
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 10 14D 0/1 0.720096
# 猛烈な雨	名詞,固有名詞,一般,*,*,*,猛烈な雨,モウレツナアメ,モーレツナアメ
# により	助詞,格助詞,連語,*,*,*,により,ニヨリ,ニヨリ
# 、	記号,読点,*,*,*,*,、,、,、
# * 11 12D 0/1 0.647941
# 進路	名詞,一般,*,*,*,*,進路,シンロ,シンロ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 12 13D 0/1 1.353491
# アッ	感動詞,*,*,*,*,*,アッ,アッ,アッ
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# * 13 14D 0/1 0.990668
# 間	名詞,一般,*,*,*,*,間,マ,マ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 14 18D 0/0 0.066662
# 冠水	名詞,サ変接続,*,*,*,*,冠水,カンスイ,カンスイ
# 、	記号,読点,*,*,*,*,、,、,、
# * 15 17D 0/1 1.008539
# 前	名詞,副詞可能,*,*,*,*,前,マエ,マエ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 16 17D 0/0 1.946826
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# * 17 18D 0/1 2.883516
# 見え	動詞,自立,*,*,一段,未然形,見える,ミエ,ミエ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# * 18 21D 0/1 0.176163
# 状況	名詞,一般,*,*,*,*,状況,ジョウキョウ,ジョーキョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# * 19 20D 1/2 1.566483
# 冠水	名詞,サ変接続,*,*,*,*,冠水,カンスイ,カンスイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 20 21D 0/1 0.577562
# 場所	名詞,一般,*,*,*,*,場所,バショ,バショ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 21 28D 0/0 1.984006
# 突入	名詞,サ変接続,*,*,*,*,突入,トツニュウ,トツニュー
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# 　	記号,空白,*,*,*,*,　,　,
# * 22 27D 0/0 0.669707
# あえなく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,あえない,アエナク,アエナク
# * 23 24D 3/5 1.082500
# 水没	名詞,サ変接続,*,*,*,*,水没,スイボツ,スイボツ
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# 膝	名詞,一般,*,*,*,*,膝,ヒザ,ヒザ
# まで	助詞,副助詞,*,*,*,*,まで,マデ,マデ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 24 25D 0/1 1.135067
# 水	名詞,一般,*,*,*,*,水,ミズ,ミズ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 25 27D 0/0 0.416479
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# * 26 27D 0/1 1.598482
# 愛車	名詞,一般,*,*,*,*,愛車,アイシャ,アイシャ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 27 28D 0/1 2.030952
# 押し	動詞,自立,*,*,五段・サ行,連用形,押す,オシ,オシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 28 45D 0/0 -0.748347
# 避難	名詞,サ変接続,*,*,*,*,避難,ヒナン,ヒナン
# 。	記号,句点,*,*,*,*,。,。,。
# * 29 30D 0/0 2.994602
# その間	名詞,副詞可能,*,*,*,*,その間,ソノカン,ソノカン
# * 30 45D 3/6 -0.748347
# ３	名詞,数,*,*,*,*,３,サン,サン
# ０	名詞,数,*,*,*,*,０,ゼロ,ゼロ
# 分	名詞,接尾,助数詞,*,*,*,分,フン,フン
# 程度	名詞,接尾,一般,*,*,*,程度,テイド,テイド
# でし	助動詞,*,*,*,特殊・デス,連用形,です,デシ,デシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# * 31 33D 1/2 0.754191
# 避難	名詞,サ変接続,*,*,*,*,避難,ヒナン,ヒナン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# * 32 33D 2/3 2.194151
# 電話	名詞,サ変接続,*,*,*,*,電話,デンワ,デンワ
# 連絡	名詞,サ変接続,*,*,*,*,連絡,レンラク,レンラク
# 等	名詞,接尾,一般,*,*,*,等,トウ,トー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 33 38D 0/0 0.786713
# 行ない	動詞,自立,*,*,五段・ワ行促音便,連用形,行なう,オコナイ,オコナイ
# 、	記号,読点,*,*,*,*,、,、,、
# * 34 36D 0/0 0.187954
# ふと	副詞,一般,*,*,*,*,ふと,フト,フト
# * 35 36D 0/1 1.026517
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 36 37D 1/2 1.415244
# 水没	名詞,サ変接続,*,*,*,*,水没,スイボツ,スイボツ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 37 38D 0/1 1.816760
# 場所	名詞,一般,*,*,*,*,場所,バショ,バショ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 38 45D 0/1 -0.748347
# 振り返る	動詞,自立,*,*,五段・ラ行,基本形,振り返る,フリカエル,フリカエル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# 　	記号,空白,*,*,*,*,　,　,
# * 39 45D 0/0 -0.748347
# すでに	副詞,一般,*,*,*,*,すでに,スデニ,スデニ
# * 40 41D 0/1 1.053103
# 水	名詞,一般,*,*,*,*,水,ミズ,ミズ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 41 45D 6/7 -0.748347
# 引け	動詞,自立,*,*,一段,連用形,引ける,ヒケ,ヒケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# おかげ	名詞,一般,*,*,*,*,おかげ,オカゲ,オカゲ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 42 45D 0/1 -0.748347
# 愛車	名詞,一般,*,*,*,*,愛車,アイシャ,アイシャ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 43 44D 0/0 0.037438
# 廃車	名詞,一般,*,*,*,*,廃車,ハイシャ,ハイシャ
# 、	記号,読点,*,*,*,*,、,、,、
# * 44 45D 0/0 -0.748347
# 辛い	形容詞,自立,*,*,形容詞・アウオ段,基本形,辛い,ツライ,ツライ
# * 45 -1D 0/1 0.000000
# 記憶	名詞,サ変接続,*,*,*,*,記憶,キオク,キオク
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ・	記号,一般,*,*,*,*,・,・,・
# ・	記号,一般,*,*,*,*,・,・,・
# EOS
#
# * 0 1D 0/1 2.590698
# 東海	名詞,固有名詞,地域,一般,*,*,東海,トウカイ,トーカイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 1 5D 0/2 1.491986
# 言っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,言う,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 、	記号,読点,*,*,*,*,、,、,、
# * 2 3D 1/1 1.710341
# 静岡	名詞,固有名詞,地域,一般,*,*,静岡,シズオカ,シズオカ
# なのか	名詞,固有名詞,人名,名,*,*,なのか,ナノカ,ナノカ
# 、	記号,読点,*,*,*,*,、,、,、
# * 3 4D 1/1 1.383871
# 愛知	名詞,固有名詞,人名,姓,*,*,愛知,アイチ,アイチ
# なのか	名詞,固有名詞,人名,名,*,*,なのか,ナノカ,ナノカ
# 、	記号,読点,*,*,*,*,、,、,、
# * 4 5D 0/1 4.169903
# 三重	名詞,固有名詞,人名,姓,*,*,三重,ミエ,ミエ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 5 12D 2/3 2.307209
# 南部	名詞,一般,*,*,*,*,南部,ナンブ,ナンブ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 。	記号,句点,*,*,*,*,。,。,。
# * 6 7D 0/1 2.921450
# 関東甲信	名詞,固有名詞,一般,*,*,*,関東甲信,カントウコウシン,カントーコーシン
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 7 12D 0/2 2.102950
# 言っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,言う,イッ,イッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 、	記号,読点,*,*,*,*,、,、,、
# * 8 9D 1/2 1.752992
# 東京	名詞,固有名詞,地域,一般,*,*,東京,トウキョウ,トーキョー
# 神奈川	名詞,固有名詞,地域,一般,*,*,神奈川,カナガワ,カナガワ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 9 10D 0/1 2.857742
# 街	名詞,一般,*,*,*,*,街,マチ,マチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 10 12D 2/3 3.815439
# 方	名詞,非自立,一般,*,*,*,方,ホウ,ホー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 、	記号,読点,*,*,*,*,、,、,、
# * 11 12D 0/1 4.460645
# 長野	名詞,固有名詞,地域,一般,*,*,長野,ナガノ,ナガノ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 12 17D 2/3 -0.883555
# 山奥	名詞,一般,*,*,*,*,山奥,ヤマオク,ヤマオク
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 。	記号,句点,*,*,*,*,。,。,。
# * 13 14D 0/0 1.486766
# この	連体詞,*,*,*,*,*,この,コノ,コノ
# * 14 17D 0/1 -0.883555
# 区分	名詞,サ変接続,*,*,*,*,区分,クブン,クブン
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# * 15 17D 0/0 -0.883555
# おお	感動詞,*,*,*,*,*,おお,オオ,オー
# * 16 17D 0/0 -0.883555
# ざっ	副詞,一般,*,*,*,*,ざっ,ザッ,ザッ
# * 17 -1D 0/0 0.000000
# ぱすぎる	名詞,一般,*,*,*,*,*
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 1.669350
# コロナ禍	名詞,固有名詞,一般,*,*,*,コロナ禍,コロナカ,コロナカ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 4D 0/1 0.170180
# おかげ	名詞,一般,*,*,*,*,おかげ,オカゲ,オカゲ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 2 4D 0/1 0.098812
# テレワーク	名詞,固有名詞,一般,*,*,*,テレワーク,テレワーク,テレワーク
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 3 4D 0/1 1.487988
# 以前	名詞,副詞可能,*,*,*,*,以前,イゼン,イゼン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 4 7D 0/1 0.719981
# 比べれ	動詞,自立,*,*,一段,仮定形,比べる,クラベレ,クラベレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# * 5 7D 0/0 1.433132
# ずっと	副詞,一般,*,*,*,*,ずっと,ズット,ズット
# * 6 7D 0/1 2.419901
# ポピュラー	名詞,一般,*,*,*,*,ポピュラー,ポピュラー,ポピュラー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 7 8D 0/2 0.065044
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# し	助詞,接続助詞,*,*,*,*,し,シ,シ
# 、	記号,読点,*,*,*,*,、,、,、
# * 8 9D 1/2 3.021595
# 活用	名詞,サ変接続,*,*,*,*,活用,カツヨウ,カツヨー
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 9 22D 0/2 1.734953
# いい	動詞,自立,*,*,五段・ワ行促音便,連用形,いう,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# * 10 14D 0/1 0.691067
# 明日	名詞,副詞可能,*,*,*,*,明日,アシタ,アシタ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 11 12D 0/1 1.367954
# 可能	名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 12 14D 0/0 1.175019
# 限り	名詞,非自立,副詞可能,*,*,*,限り,カギリ,カギリ
# * 13 14D 1/2 2.852909
# 在宅	名詞,サ変接続,*,*,*,*,在宅,ザイタク,ザイタク
# 勤務	名詞,サ変接続,*,*,*,*,勤務,キンム,キンム
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 14 20D 0/1 0.256659
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# * 15 20D 0/1 0.593970
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 16 17D 0/0 1.139988
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# * 17 18D 0/1 1.544855
# 準備	名詞,サ変接続,*,*,*,*,準備,ジュンビ,ジュンビ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 18 19D 0/0 0.791601
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# * 19 20D 0/0 0.197352
# 次第	名詞,副詞可能,*,*,*,*,次第,シダイ,シダイ
# 、	記号,読点,*,*,*,*,、,、,、
# * 20 21D 2/3 1.923666
# 帰宅	名詞,サ変接続,*,*,*,*,帰宅,キタク,キタク
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 21 22D 0/1 3.007787
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 22 30D 0/1 -0.440814
# 思い	動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# * 23 25D 0/1 1.787765
# 交通機関	名詞,固有名詞,一般,*,*,*,交通機関,コウツウキカン,コーツーキカン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 24 25D 0/1 2.052326
# 影響	名詞,サ変接続,*,*,*,*,影響,エイキョウ,エイキョー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 25 26D 1/2 2.552282
# 出る	動詞,自立,*,*,一段,基本形,出る,デル,デル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 26 30D 2/5 -0.440814
# 避け	動詞,自立,*,*,一段,未然形,避ける,サケ,サケ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# そう	名詞,接尾,助動詞語幹,*,*,*,そう,ソウ,ソー
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# * 27 29D 1/2 1.117618
# こちら	名詞,代名詞,一般,*,*,*,こちら,コチラ,コチラ
# 側	名詞,接尾,一般,*,*,*,側,ガワ,ガワ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 28 29D 0/1 2.222491
# 対策	名詞,サ変接続,*,*,*,*,対策,タイサク,タイサク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 29 30D 0/1 -0.440814
# 取る	動詞,自立,*,*,五段・ラ行,基本形,取る,トル,トル
# しか	助詞,係助詞,*,*,*,*,しか,シカ,シカ
# * 30 -1D 0/1 0.000000
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 2D 0/0 1.471474
# ずっと	副詞,一般,*,*,*,*,ずっと,ズット,ズット
# * 1 2D 0/1 2.543817
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 2 6D 0/2 1.826822
# 降ら	動詞,自立,*,*,五段・ラ行,未然形,降る,フラ,フラ
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# * 3 4D 0/0 0.017316
# やっと	副詞,一般,*,*,*,*,やっと,ヤット,ヤット
# * 4 5D 0/1 1.938236
# 雨か	名詞,サ変接続,*,*,*,*,雨下,ウカ,ウカ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 5 6D 0/1 1.068406
# 思え	動詞,自立,*,*,五段・ワ行促音便,仮定形,思う,オモエ,オモエ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# * 6 8D 2/2 1.153880
# 災害	名詞,一般,*,*,*,*,災害,サイガイ,サイガイ
# 級	名詞,接尾,一般,*,*,*,級,キュウ,キュー
# 土砂降り	名詞,一般,*,*,*,*,土砂降り,ドシャブリ,ドシャブリ
# 。	記号,句点,*,*,*,*,。,。,。
# * 7 8D 0/2 1.972482
# 天災	名詞,一般,*,*,*,*,天災,テンサイ,テンサイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 8 12D 0/0 0.841968
# 無力	名詞,形容動詞語幹,*,*,*,*,無力,ムリョク,ムリョク
# 。	記号,句点,*,*,*,*,。,。,。
# * 9 10D 0/0 1.448452
# この	連体詞,*,*,*,*,*,この,コノ,コノ
# * 10 11D 0/1 1.193300
# 梅雨前線	名詞,固有名詞,一般,*,*,*,梅雨前線,バイウゼンセン,バイウゼンセン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 11 12D 0/1 1.048457
# 過ぎ	動詞,自立,*,*,一段,連用形,過ぎる,スギ,スギ
# たら	助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ
# * 12 22D 1/3 -1.905445
# 梅雨明け	名詞,一般,*,*,*,*,梅雨明け,ツユアケ,ツユアケ
# しそう	名詞,サ変接続,*,*,*,*,しそう,シソウ,シソー
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# なー	助詞,終助詞,*,*,*,*,なー,ナー,ナー
# 。	記号,句点,*,*,*,*,。,。,。
# * 13 14D 1/2 1.197736
# 災害	名詞,一般,*,*,*,*,災害,サイガイ,サイガイ
# 級	名詞,接尾,一般,*,*,*,級,キュウ,キュー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 14 15D 0/1 2.029421
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 15 22D 0/1 -1.905445
# 時	名詞,非自立,副詞可能,*,*,*,時,トキ,トキ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 16 22D 0/2 -1.905445
# 間違っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,間違う,マチガッ,マチガッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 17 18D 1/2 0.604545
# 田んぼ	名詞,一般,*,*,*,*,田んぼ,タンボ,タンボ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 18 20D 0/1 1.280500
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# * 19 20D 0/1 1.827154
# 海見	名詞,固有名詞,人名,姓,*,*,海見,カイミ,カイミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 20 22D 0/1 -1.905445
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# 、	記号,読点,*,*,*,*,、,、,、
# * 21 22D 0/1 -1.905445
# 川見	名詞,固有名詞,人名,姓,*,*,川見,カワミ,カワミ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 22 -1D 2/5 0.000000
# 行っ	動詞,自立,*,*,五段・カ行促音便,連用タ接続,行く,イッ,イッ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# し	動詞,自立,*,*,サ変・スル,未然形,する,シ,シ
# ない	助動詞,*,*,*,特殊・ナイ,連用デ接続,ない,ナイ,ナイ
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# ください	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,くださる,クダサイ,クダサイ
# EOS
#
# * 0 9D 0/1 -0.576686
# てるてる坊主	名詞,一般,*,*,*,*,照る照る坊主,テルテルボウズ,テルテルボーズ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# * 1 2D 0/0 1.487841
# もう	副詞,一般,*,*,*,*,もう,モウ,モー
# * 2 4D 0/1 0.567776
# 無理	名詞,形容動詞語幹,*,*,*,*,無理,ムリ,ムリ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# * 3 4D 1/2 1.466485
# ！	記号,一般,*,*,*,*,！,！,！
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 4 9D 1/3 -0.576686
# 能力	名詞,一般,*,*,*,*,能力,ノウリョク,ノーリョク
# 超え	動詞,自立,*,*,一段,連用形,超える,コエ,コエ
# 過ぎ	動詞,非自立,*,*,一段,連用形,過ぎる,スギ,スギ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ！	記号,一般,*,*,*,*,！,！,！
# * 5 7D 1/1 1.292492
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# 以上	名詞,非自立,副詞可能,*,*,*,以上,イジョウ,イジョー
# * 6 7D 0/1 1.398192
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 7 9D 1/4 -0.576686
# 期待	名詞,サ変接続,*,*,*,*,期待,キタイ,キタイ
# し	動詞,自立,*,*,サ変・スル,未然形,する,シ,シ
# ない	助動詞,*,*,*,特殊・ナイ,連用デ接続,ない,ナイ,ナイ
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# ください	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,くださる,クダサイ,クダサイ
# * 8 9D 0/1 -0.576686
# ！	記号,一般,*,*,*,*,！,！,！
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# * 9 -1D 0/3 0.000000
# 追い詰め	動詞,自立,*,*,一段,未然形,追い詰める,オイツメ,オイツメ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 1.873452
# 早く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,早い,ハヤク,ハヤク
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 1 2D 1/2 1.924005
# 梅雨入り	名詞,サ変接続,*,*,*,*,梅雨入り,ツユイリ,ツユイリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 2 3D 0/2 0.891031
# 割	名詞,一般,*,*,*,*,割,ワリ,ワリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 3 4D 0/3 1.215151
# 空梅雨	名詞,一般,*,*,*,*,空梅雨,カラツユ,カラツユ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 4 8D 0/2 0.143598
# 思っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,思う,オモッ,オモッ
# て	動詞,非自立,*,*,一段,連用形,てる,テ,テ
# たら	助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ
# * 5 6D 0/1 2.053504
# 7月	名詞,固有名詞,一般,*,*,*,7月,シチガツ,シチガツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 6 7D 0/1 1.649976
# 入っ	動詞,自立,*,*,五段・ラ行,連用タ接続,入る,ハイッ,ハイッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 7 8D 0/0 0.006729
# 途端	名詞,非自立,副詞可能,*,*,*,途端,トタン,トタン
# * 8 16D 0/0 -2.385611
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# 。	記号,句点,*,*,*,*,。,。,。
# * 9 11D 0/0 0.718542
# 既に	副詞,一般,*,*,*,*,既に,スデニ,スデニ
# * 10 11D 0/1 0.798408
# 散歩	名詞,サ変接続,*,*,*,*,散歩,サンポ,サンポ
# へ	助詞,格助詞,一般,*,*,*,へ,ヘ,エ
# * 11 12D 3/4 1.345125
# 行け	動詞,自立,*,*,五段・カ行促音便,仮定形,行く,イケ,イケ
# な	形容詞,自立,*,*,形容詞・アウオ段,ガル接続,ない,ナ,ナ
# さ	名詞,接尾,特殊,*,*,*,さ,サ,サ
# そう	名詞,接尾,助動詞語幹,*,*,*,そう,ソウ,ソー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 12 13D 0/1 1.280311
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 13 15D 0/1 0.624571
# 犬	名詞,一般,*,*,*,*,犬,イヌ,イヌ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 14 15D 0/1 1.348910
# ベランダ	名詞,一般,*,*,*,*,ベランダ,ベランダ,ベランダ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 15 16D 1/2 -2.385611
# イラッと	副詞,一般,*,*,*,*,イラッと,イラット,イラット
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ...
# 降っ	動詞,自立,*,*,五段・ラ行,連用タ接続,降る,フッ,フッ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# やん	動詞,自立,*,*,五段・マ行,連用タ接続,やむ,ヤン,ヤン
# だり	助詞,並立助詞,*,*,*,*,だり,ダリ,ダリ
# 。	記号,句点,*,*,*,*,。,。,。
# * 4 5D 3/4 1.902769
# 外出	名詞,サ変接続,*,*,*,*,外出,ガイシュツ,ガイシュツ
# 中	名詞,接尾,副詞可能,*,*,*,中,チュウ,チュー
# ドシャ	名詞,一般,*,*,*,*,土砂,ドシャ,ドシャ
# 降り	名詞,一般,*,*,*,*,降り,フリ,フリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 5 7D 0/0 0.270476
# 遭い	動詞,自立,*,*,五段・ワ行促音便,連用形,遭う,アイ,アイ
# 、	記号,読点,*,*,*,*,、,、,、
# * 6 7D 0/1 1.803140
# 傘	名詞,一般,*,*,*,*,傘,カサ,カサ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 7 9D 0/2 1.321066
# 差し	動詞,自立,*,*,五段・サ行,連用形,差す,サシ,サシ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 8 9D 0/1 1.107138
# 足元	名詞,一般,*,*,*,*,足元,アシモト,アシモト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 9 13D 0/0 0.844900
# ずぶ濡れ	名詞,一般,*,*,*,*,ずぶ濡れ,ズブヌレ,ズブヌレ
# 。	記号,句点,*,*,*,*,。,。,。
# * 10 13D 1/2 1.353576
# 帰宅	名詞,サ変接続,*,*,*,*,帰宅,キタク,キタク
# すれ	動詞,自立,*,*,サ変・スル,仮定形,する,スレ,スレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# * 11 13D 0/1 1.126955
# 室内	名詞,一般,*,*,*,*,室内,シツナイ,シツナイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 12 13D 1/2 1.093797
# 30度	名詞,固有名詞,一般,*,*,*,30度,サンジュウド,サンジュウド
# 越え	動詞,自立,*,*,一段,連用形,越える,コエ,コエ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 13 16D 0/0 -3.192545
# ムシムシ	副詞,一般,*,*,*,*,ムシムシ,ムシムシ,ムシムシ
# 。	記号,句点,*,*,*,*,。,。,。
# * 14 15D 0/1 1.208797
# さんざん	副詞,助詞類接続,*,*,*,*,さんざん,サンザン,サンザン
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 15 16D 0/1 -3.192545
# 天気	名詞,一般,*,*,*,*,天気,テンキ,テンキ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 16 -1D 0/0 0.000000
# 降参	名詞,サ変接続,*,*,*,*,降参,コウサン,コーサン
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 1.833577
# ５月	名詞,副詞可能,*,*,*,*,5月,ゴガツ,ゴガツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 2D 1/2 1.194032
# 連休	名詞,一般,*,*,*,*,連休,レンキュウ,レンキュー
# 後	名詞,接尾,副詞可能,*,*,*,後,ゴ,ゴ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 2 5D 2/3 1.313549
# 梅雨入り	名詞,サ変接続,*,*,*,*,梅雨入り,ツユイリ,ツユイリ
# 宣言	名詞,サ変接続,*,*,*,*,宣言,センゲン,センゲン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 3 5D 0/0 1.355064
# もうすぐ	副詞,一般,*,*,*,*,もうすぐ,モウスグ,モースグ
# * 4 5D 1/2 2.057801
# ２	名詞,数,*,*,*,*,２,ニ,ニ
# ヶ月	名詞,接尾,助数詞,*,*,*,ヶ月,カゲツ,カゲツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 5 6D 0/1 1.068687
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# * 6 7D 0/1 1.068687
# 梅雨明け	名詞,一般,*,*,*,*,梅雨明け,ツユアケ,ツユアケ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 7 -1D 2/4 0.000000
# いつ	名詞,代名詞,一般,*,*,*,いつ,イツ,イツ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# でしょ	助動詞,*,*,*,特殊・デス,未然形,です,デショ,デショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# ？	記号,一般,*,*,*,*,？,？,？
# EOS
#
# * 0 1D 2/3 0.773148
# あぁ	感動詞,*,*,*,*,*,あぁ,アァ,アー
# 〜	記号,一般,*,*,*,*,〜,〜,〜
# 豪雨	名詞,一般,*,*,*,*,豪雨,ゴウウ,ゴーウ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 4D 0/1 1.217690
# 時間	名詞,副詞可能,*,*,*,*,時間,ジカン,ジカン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 2 4D 0/1 1.118056
# 出勤	名詞,サ変接続,*,*,*,*,出勤,シュッキン,シュッキン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 3 4D 0/0 2.288786
# ぁ	名詞,一般,*,*,*,*,*
# * 4 5D 0/3 1.217690
# 行き	動詞,自立,*,*,五段・カ行促音便,連用形,行く,イキ,イキ
# たく	助動詞,*,*,*,特殊・タイ,連用テ接続,たい,タク,タク
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# なぁ	助詞,終助詞,*,*,*,*,なぁ,ナァ,ナー
# 、	記号,読点,*,*,*,*,、,、,、
# * 5 -1D 0/2 0.000000
# 休み	動詞,自立,*,*,五段・マ行,連用形,休む,ヤスミ,ヤスミ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# わ	助詞,終助詞,*,*,*,*,わ,ワ,ワ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 3D 0/1 0.838316
# 天候	名詞,一般,*,*,*,*,天候,テンコウ,テンコー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 1 2D 0/1 1.401772
# 時々刻々	名詞,一般,*,*,*,*,時々刻々,ジジコクコク,ジジコクコク
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# * 2 3D 0/0 2.691792
# 変わる	動詞,自立,*,*,五段・ラ行,基本形,変わる,カワル,カワル
# * 3 7D 0/2 1.025916
# もの	名詞,非自立,一般,*,*,*,もの,モノ,モノ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# 、	記号,読点,*,*,*,*,、,、,、
# * 4 5D 0/1 1.412519
# 一時	名詞,副詞可能,*,*,*,*,一時,イチジ,イチジ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 5 7D 0/1 2.771994
# 判断ミス	名詞,固有名詞,一般,*,*,*,判断ミス,ハンダンミス,ハンダンミス
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 6 7D 0/1 3.769108
# 命取り	名詞,一般,*,*,*,*,命取り,イノチトリ,イノチトリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 7 12D 0/3 0.213988
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# かね	動詞,非自立,*,*,一段,連用形,かねる,カネ,カネ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# 。	記号,句点,*,*,*,*,。,。,。
# * 8 12D 0/1 1.372149
# 事	名詞,一般,*,*,*,*,事,コト,コト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 9 10D 1/2 4.628876
# 「	記号,括弧開,*,*,*,*,「,「,「
# 命	名詞,一般,*,*,*,*,命,イノチ,イノチ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 10 12D 0/2 3.011297
# 守る	動詞,自立,*,*,五段・ラ行,基本形,守る,マモル,マモル
# 」	記号,括弧閉,*,*,*,*,」,」,」
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 11 12D 1/2 2.699238
# やり	動詞,自立,*,*,五段・ラ行,連用形,やる,ヤリ,ヤリ
# すぎ	名詞,接尾,一般,*,*,*,すぎ,スギ,スギ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 12 20D 0/2 1.514290
# あり	動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# 。	記号,句点,*,*,*,*,。,。,。
# * 13 17D 0/1 0.129898
# 私たち	名詞,固有名詞,一般,*,*,*,私たち,ワタシタチ,ワタシタチ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 14 15D 0/1 0.605817
# 気象庁	名詞,固有名詞,組織,*,*,*,気象庁,キショウチョウ,キショーチョー
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# * 15 16D 0/1 1.511154
# 百戦錬磨	名詞,一般,*,*,*,*,百戦錬磨,ヒャクセンレンマ,ヒャクセンレンマ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 16 17D 1/2 0.534506
# プロ	名詞,一般,*,*,*,*,プロ,プロ,プロ
# たち	名詞,接尾,一般,*,*,*,たち,タチ,タチ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# * 17 18D 0/1 1.686368
# もたらさ	動詞,自立,*,*,五段・サ行,未然形,もたらす,モタラサ,モタラサ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# * 18 19D 0/1 1.847570
# 情報	名詞,一般,*,*,*,*,情報,ジョウホウ,ジョーホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 19 20D 1/3 1.991197
# 有効活用	名詞,サ変接続,*,*,*,*,有効活用,ユウコウカツヨウ,ユーコーカツヨー
# し	動詞,自立,*,*,サ変・スル,未然形,する,シ,シ
# なけれ	助動詞,*,*,*,特殊・ナイ,仮定形,ない,ナケレ,ナケレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# * 20 29D 0/3 -2.304518
# なり	動詞,非自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# * 21 22D 1/2 0.966922
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# しろ	動詞,自立,*,*,サ変・スル,命令ｒｏ,する,シロ,シロ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 22 25D 0/2 0.563952
# いう	動詞,自立,*,*,五段・ワ行促音便,基本形,いう,イウ,イウ
# より	助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 23 24D 0/2 1.713391
# 生き	動詞,自立,*,*,一段,連用形,生きる,イキ,イキ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# * 24 25D 1/2 0.889938
# 事	名詞,非自立,一般,*,*,*,事,コト,コト
# 自体	名詞,一般,*,*,*,*,自体,ジタイ,ジタイ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 25 29D 0/2 -2.304518
# 勉強	名詞,サ変接続,*,*,*,*,勉強,ベンキョウ,ベンキョー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# * 26 27D 1/2 3.280371
# 「	記号,括弧開,*,*,*,*,「,「,「
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 27 28D 0/0 1.668032
# 生きる	動詞,自立,*,*,一段,基本形,生きる,イキル,イキル
# 」	記号,括弧閉,*,*,*,*,」,」,」
# * 28 29D 0/1 -2.304518
# 事	名詞,一般,*,*,*,*,事,コト,コト
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 29 -1D 1/3 0.000000
# 集中	名詞,サ変接続,*,*,*,*,集中,シュウチュウ,シューチュー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ましょ	助動詞,*,*,*,特殊・マス,未然ウ接続,ます,マショ,マショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 1.166277
# 美容師	名詞,一般,*,*,*,*,美容師,ビヨウシ,ビヨウシ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# * 1 2D 0/1 1.843792
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 2 5D 2/4 1.745484
# 予約	名詞,サ変接続,*,*,*,*,予約,ヨヤク,ヨヤク
# とか	助詞,並立助詞,*,*,*,*,とか,トカ,トカ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# * 3 4D 0/1 0.826419
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 4 5D 1/3 1.448249
# 無理	名詞,形容動詞語幹,*,*,*,*,無理,ムリ,ムリ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# でも	助詞,副助詞,*,*,*,*,でも,デモ,デモ
# * 5 6D 5/6 1.745484
# 来	動詞,自立,*,*,カ変・来ル,未然形,来る,コ,コ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# と	助詞,接続助詞,*,*,*,*,と,ト,ト
# いけ	動詞,非自立,*,*,一段,未然形,いける,イケ,イケ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 6 -1D 0/0 0.000000
# 辛い	形容詞,自立,*,*,形容詞・アウオ段,基本形,辛い,ツライ,ツライ
# EOS
#
# * 0 1D 0/1 2.157830
# ハザードマップ	名詞,固有名詞,一般,*,*,*,ハザードマップ,ハザードマップ,ハザードマップ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 1 5D 1/2 1.362733
# 確認	名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 2 3D 0/1 1.829774
# 早め	名詞,一般,*,*,*,*,早め,ハヤメ,ハヤメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 3 4D 0/1 1.017001
# 非難	名詞,サ変接続,*,*,*,*,非難,ヒナン,ヒナン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 4 5D 0/1 1.153732
# 心がけ	動詞,自立,*,*,一段,連用形,心がける,ココロガケ,ココロガケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# * 5 6D 1/2 1.362733
# 対応	名詞,サ変接続,*,*,*,*,対応,タイオウ,タイオー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# しか	助詞,係助詞,*,*,*,*,しか,シカ,シカ
# * 6 -1D 0/1 0.000000
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 8D 1/1 1.897294
# 民間企業	名詞,固有名詞,一般,*,*,*,民間企業,ミンカンキギョウ,ミンカンキギョー
# はね	動詞,自立,*,*,一段,連用形,はねる,ハネ,ハネ
# * 1 2D 0/1 1.113729
# 屋外	名詞,一般,*,*,*,*,屋外,オクガイ,オクガイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 2 3D 4/4 1.609648
# 現場	名詞,一般,*,*,*,*,現場,ゲンバ,ゲンバ
# 作業	名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# * 3 8D 0/0 1.764419
# 限り	名詞,非自立,副詞可能,*,*,*,限り,カギリ,カギリ
# * 4 8D 0/2 2.057920
# 大雨	名詞,一般,*,*,*,*,大雨,オオアメ,オーアメ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# * 5 6D 0/3 0.471787
# 危険	名詞,形容動詞語幹,*,*,*,*,危険,キケン,キケン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# * 6 8D 1/2 2.838070
# 仕事	名詞,サ変接続,*,*,*,*,仕事,シゴト,シゴト
# 止め	動詞,自立,*,*,一段,連用形,止める,トメ,トメ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# * 7 8D 0/1 3.972256
# 終わり	動詞,自立,*,*,五段・ラ行,連用形,終わる,オワリ,オワリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 8 19D 4/8 -1.544727
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれ	動詞,非自立,*,*,一段・クレル,未然形,くれる,クレ,クレ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ！	記号,一般,*,*,*,*,！,！,！
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# * 9 15D 0/0 1.030419
# 結局	名詞,副詞可能,*,*,*,*,結局,ケッキョク,ケッキョク
# * 10 15D 0/1 0.681992
# ラッシュ	名詞,一般,*,*,*,*,ラッシュ,ラッシュ,ラッシュ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 11 15D 0/1 1.552463
# 変わら	動詞,自立,*,*,五段・ラ行,未然形,変わる,カワラ,カワラ
# ず	助動詞,*,*,*,特殊・ヌ,連用ニ接続,ぬ,ズ,ズ
# * 12 14D 0/1 1.784051
# 余計	名詞,形容動詞語幹,*,*,*,*,余計,ヨケイ,ヨケイ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 13 14D 0/1 1.858549
# 事故	名詞,一般,*,*,*,*,事故,ジコ,ジコ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# * 14 15D 0/1 2.190077
# トラブル	名詞,一般,*,*,*,*,トラブル,トラブル,トラブル
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 15 19D 0/0 -1.544727
# 起きる	動詞,自立,*,*,一段,基本形,起きる,オキル,オキル
# ！	記号,一般,*,*,*,*,！,！,！
# * 16 17D 0/1 0.320913
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 17 18D 0/0 0.014411
# ご時世	名詞,一般,*,*,*,*,ご時世,ゴジセイ,ゴジセイ
# 、	記号,読点,*,*,*,*,、,、,、
# * 18 19D 0/2 -1.544727
# 密	名詞,一般,*,*,*,*,密,ミツ,ミツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 19 -1D 1/3 0.000000
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ！	記号,一般,*,*,*,*,！,！,！
# EOS
#
# * 0 2D 0/1 2.255276
# 梅雨	名詞,一般,*,*,*,*,梅雨,ツユ,ツユ
# って	助詞,格助詞,連語,*,*,*,って,ッテ,ッテ
# 、	記号,読点,*,*,*,*,、,、,、
# * 1 2D 0/0 2.082665
# しとしと	副詞,一般,*,*,*,*,しとしと,シトシト,シトシト
# * 2 5D 8/8 -1.912430
# 降る	動詞,自立,*,*,五段・ラ行,基本形,降る,フル,フル
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# じゃ	助詞,副助詞,*,*,*,*,じゃ,ジャ,ジャ
# なかっ	助動詞,*,*,*,特殊・ナイ,連用タ接続,ない,ナカッ,ナカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# っけ	助詞,終助詞,*,*,*,*,っけ,ッケ,ッケ
# …	記号,一般,*,*,*,*,…,…,…
# 毎日	名詞,固有名詞,組織,*,*,*,毎日,マイニチ,マイニチ
# 豪雨	名詞,一般,*,*,*,*,豪雨,ゴウウ,ゴーウ
# 。	記号,句点,*,*,*,*,。,。,。
# * 3 5D 0/1 -1.912430
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 4 5D 0/0 -1.912430
# もはや	副詞,助詞類接続,*,*,*,*,もはや,モハヤ,モハヤ
# * 5 -1D 0/4 0.000000
# 梅雨	名詞,一般,*,*,*,*,梅雨,ツユ,ツユ
# じゃ	助詞,副助詞,*,*,*,*,じゃ,ジャ,ジャ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/0 0.364100
# ここ	名詞,代名詞,一般,*,*,*,ここ,ココ,ココ
# * 1 2D 0/2 1.932654
# 3年	名詞,固有名詞,一般,*,*,*,3年,サンネン,サンネン
# くらい	助詞,副助詞,*,*,*,*,くらい,クライ,クライ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 2 3D 3/4 1.859891
# 聞く	動詞,自立,*,*,五段・カ行イ音便,基本形,聞く,キク,キク
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# * 3 10D 0/0 1.369815
# 線状降水帯	名詞,固有名詞,一般,*,*,*,線状降水帯,センジョウコウスイタイ,センジョーコースイタイ
# 。	記号,句点,*,*,*,*,。,。,。
# * 4 6D 0/1 1.763586
# 昔	名詞,副詞可能,*,*,*,*,昔,ムカシ,ムカシ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# * 5 6D 0/1 2.092711
# 発生	名詞,サ変接続,*,*,*,*,発生,ハッセイ,ハッセイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 6 10D 0/4 1.129949
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# い	動詞,非自立,*,*,一段,連用形,いる,イ,イ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ので	助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ
# * 7 10D 0/0 2.279961
# しょうが	名詞,一般,*,*,*,*,しょうが,ショウガ,ショーガ
# 、	記号,読点,*,*,*,*,、,、,、
# * 8 10D 0/1 2.679513
# ここ	名詞,代名詞,一般,*,*,*,ここ,ココ,ココ
# まで	助詞,副助詞,*,*,*,*,まで,マデ,マデ
# * 9 10D 0/1 2.893863
# 頻繁	名詞,形容動詞語幹,*,*,*,*,頻繁,ヒンパン,ヒンパン
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 10 19D 3/6 1.077109
# 発生	名詞,サ変接続,*,*,*,*,発生,ハッセイ,ハッセイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# なかっ	形容詞,自立,*,*,形容詞・アウオ段,連用タ接続,ない,ナカッ,ナカッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# でしょ	助動詞,*,*,*,特殊・デス,未然形,です,デショ,デショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# 。	記号,句点,*,*,*,*,。,。,。
# * 11 12D 0/1 1.751213
# 梅雨	名詞,一般,*,*,*,*,梅雨,ツユ,ツユ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# * 12 15D 0/1 1.389265
# いえ	動詞,自立,*,*,五段・ワ行促音便,仮定形,いう,イエ,イエ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# * 13 14D 1/2 1.816051
# シトシト	名詞,固有名詞,一般,*,*,*,*
# 長雨	名詞,一般,*,*,*,*,長雨,ナガアメ,ナガアメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 14 15D 0/0 2.719164
# 続く	動詞,自立,*,*,五段・カ行イ音便,基本形,続く,ツヅク,ツズク
# * 15 19D 0/3 0.736645
# イメージ	名詞,サ変接続,*,*,*,*,イメージ,イメージ,イメージ
# でし	助動詞,*,*,*,特殊・デス,連用形,です,デシ,デシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# * 16 19D 0/0 2.470970
# もう	副詞,一般,*,*,*,*,もう,モウ,モー
# * 17 18D 0/0 1.514402
# そんな	連体詞,*,*,*,*,*,そんな,ソンナ,ソンナ
# * 18 19D 0/2 1.627319
# 感じ	名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 19 27D 0/2 1.290609
# なくなり	動詞,自立,*,*,五段・ラ行,連用形,なくなる,ナクナリ,ナクナリ
# まし	助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# * 20 21D 0/1 1.477364
# 梅雨	名詞,一般,*,*,*,*,梅雨,ツユ,ツユ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 21 23D 0/2 2.269585
# 入っ	動詞,自立,*,*,五段・ラ行,連用タ接続,入る,ハイッ,ハイッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 22 23D 0/0 3.084693
# 全く	副詞,助詞類接続,*,*,*,*,全く,マッタク,マッタク
# * 23 27D 0/2 0.596024
# 降ら	動詞,自立,*,*,五段・ラ行,未然形,降る,フラ,フラ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# * 24 27D 0/1 0.709276
# 夕方	名詞,副詞可能,*,*,*,*,夕方,ユウガタ,ユーガタ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# * 25 26D 0/1 0.738978
# 夏	名詞,一般,*,*,*,*,夏,ナツ,ナツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 26 27D 2/3 1.851572
# 夕立	名詞,一般,*,*,*,*,夕立,ユウダチ,ユーダチ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# * 27 32D 0/0 0.035019
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# 。	記号,句点,*,*,*,*,。,。,。
# * 28 29D 0/1 1.904104
# 梅雨	名詞,一般,*,*,*,*,梅雨,ツユ,ツユ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 29 32D 0/1 1.835892
# 終盤	名詞,一般,*,*,*,*,終盤,シュウバン,シューバン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 30 32D 0/1 2.517781
# 線状降水帯	名詞,固有名詞,一般,*,*,*,線状降水帯,センジョウコウスイタイ,センジョーコースイタイ
# による	助詞,格助詞,連語,*,*,*,による,ニヨル,ニヨル
# 、	記号,読点,*,*,*,*,、,、,、
# * 31 32D 1/2 3.838480
# 災害	名詞,一般,*,*,*,*,災害,サイガイ,サイガイ
# 級	名詞,接尾,一般,*,*,*,級,キュウ,キュー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 32 35D 0/1 -1.755347
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 。	記号,句点,*,*,*,*,。,。,。
# * 33 35D 0/1 -1.755347
# 日本	名詞,固有名詞,地域,国,*,*,日本,ニッポン,ニッポン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 34 35D 0/0 -1.755347
# もう	副詞,一般,*,*,*,*,もう,モウ,モー
# * 35 -1D 6/9 0.000000
# 温暖湿潤気候	名詞,固有名詞,一般,*,*,*,温暖湿潤気候,オンダンシツジュンキコウ,オンダンシツジュンキコー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# かも	助詞,副助詞,*,*,*,*,かも,カモ,カモ
# しれ	動詞,自立,*,*,一段,連用形,しれる,シレ,シレ
# ませ	助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 1.151272
# ある程度	副詞,助詞類接続,*,*,*,*,ある程度,アルテイド,アルテイド
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 9D 0/1 -1.029730
# 雨	名詞,一般,*,*,*,*,雨,アメ,アメ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 2 3D 0/1 2.787179
# 田んぼ	名詞,一般,*,*,*,*,田んぼ,タンボ,タンボ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# * 3 4D 1/4 1.097637
# 吸収	名詞,サ変接続,*,*,*,*,吸収,キュウシュウ,キューシュー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# くれる	動詞,非自立,*,*,一段・クレル,基本形,くれる,クレル,クレル
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# * 4 9D 0/1 -1.029730
# 問題	名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 、	記号,読点,*,*,*,*,、,、,、
# * 5 9D 0/1 -1.029730
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 6 9D 0/1 -1.029730
# 自宅	名詞,一般,*,*,*,*,自宅,ジタク,ジタク
# より	助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# * 7 9D 1/2 -1.029730
# 低い	名詞,一般,*,*,*,*,低位,テイイ,テイー
# 所	名詞,接尾,一般,*,*,*,所,ショ,ショ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 8 9D 0/1 -1.029730
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# * 9 -1D 0/2 0.000000
# 行く	動詞,自立,*,*,五段・カ行促音便,基本形,行く,イク,イク
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# ね	助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# * 0 1D 0/1 2.023125
# コロナ	名詞,一般,*,*,*,*,コロナ,コロナ,コロナ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 1 3D 2/3 2.375764
# 感染	名詞,サ変接続,*,*,*,*,感染,カンセン,カンセン
# 再	接頭詞,名詞接続,*,*,*,*,再,サイ,サイ
# 拡大	名詞,サ変接続,*,*,*,*,拡大,カクダイ,カクダイ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 2 3D 0/1 2.543931
# 現実	名詞,一般,*,*,*,*,現実,ゲンジツ,ゲンジツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# * 3 9D 1/3 0.031129
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# そう	名詞,接尾,助動詞語幹,*,*,*,そう,ソウ,ソー
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
# * 4 5D 0/0 1.721364
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# * 5 9D 0/1 0.747158
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# * 6 9D 0/1 0.349367
# 自然災害	名詞,固有名詞,一般,*,*,*,自然災害,シゼンサイガイ,シゼンサイガイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# * 7 8D 0/1 2.280550
# 速攻	名詞,サ変接続,*,*,*,*,速攻,ソッコウ,ソッコー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# * 8 9D 0/1 2.117371
# 対策	名詞,サ変接続,*,*,*,*,対策,タイサク,タイサク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# * 9 11D 1/3 0.026623
# 要求	名詞,サ変接続,*,*,*,*,要求,ヨウキュウ,ヨーキュー
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# から	助詞,接続助詞,*,*,*,*,から,カラ,カラ
# * 10 11D 0/1 2.196674
# 気	名詞,一般,*,*,*,*,気,キ,キ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# * 11 12D 0/1 0.026623
# ぬけ	動詞,自立,*,*,一段,未然形,ぬける,ヌケ,ヌケ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# * 12 -1D 1/5 0.000000
# 五輪	名詞,一般,*,*,*,*,五輪,ゴリン,ゴリン
# どころ	名詞,非自立,一般,*,*,*,どころ,ドコロ,ドコロ
# じゃ	助詞,副助詞,*,*,*,*,じゃ,ジャ,ジャ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# EOS

# %%
comments = ''
for d in range(1,11):
    comments += comments_list[d]
wordlist = wakati.parse(comments).split()
markov = {}
w1 = ""
w2 = ""
for word in wordlist:
    if w1 and w2:
        if (w1, w2) not in markov:
            markov[(w1, w2)]=[]
        markov[(w1, w2)].append(word)
    w1 = w2
    w2 = word
markov
# Out:
# {('時代', 'が'): ['違え'],
#  ('が', '違え'): ['ば'],
#  ('違え', 'ば'): ['斬首'],
#  ('ば', '斬首'): ['が'],
#  ('斬首', 'が'): ['銃殺'],
#  ('が', '銃殺'): ['な'],
#  ('銃殺', 'な'): ['ん'],
#  ('な', 'ん'): ['です'],
#  ('ん', 'です'): ['けど'],
#  ('です', 'けど'): ['ね'],
#  ('けど', 'ね'): ['。'],
#  ('ね', '。'): ['政府', '官僚'],
#  ('。', '政府'): ['は'],
#  ('政府', 'は'): ['、'],
#  ('は', '、'): ['今回', '支援金', 'その', '国民'],
#  ('、', '今回'): ['の'],
#  ('今回', 'の'): ['よう', '件', '詐欺行為'],
#  ('の', 'よう'): ['な'],
#  ('よう', 'な'): ['刑法', '重'],
#  ('な', '刑法'): ['上'],
#  ('刑法', '上'): ['の'],
#  ('上', 'の'): ['犯罪行為'],
#  ('の', '犯罪行為'): ['だけ'],
#  ('犯罪行為', 'だけ'): ['で'],
#  ('だけ', 'で'): ['なく'],
#  ('で', 'なく'): ['、'],
#  ('なく', '、'): ['特定'],
#  ('、', '特定'): ['業界'],
#  ('特定', '業界'): ['や'],
#  ('業界', 'や'): ['特定'],
#  ('や', '特定'): ['企業'],
#  ('特定', '企業'): ['から'],
#  ('企業', 'から'): ['何らかの'],
#  ('から', '何らかの'): ['便宜'],
#  ('何らかの', '便宜'): ['供与'],
#  ('便宜', '供与'): ['を'],
#  ('供与', 'を'): ['受けて'],
#  ('を', '受けて'): ['動い'],
#  ('受けて', '動い'): ['て'],
#  ('動い', 'て'): ['いる'],
#  ('て', 'いる'): ['経', '。', '官僚', 'の'],
#  ('いる', '経'): ['産'],
#  ('経', '産'): ['官僚'],
#  ('産', '官僚'): ['の'],
#  ('官僚', 'の'): ['内部監査', 'この', '信用'],
#  ('の', '内部監査'): ['と'],
#  ('内部監査', 'と'): ['処分'],
#  ('と', '処分'): ['も'],
#  ('処分', 'も'): ['併せ'],
#  ('も', '併せ'): ['て'],
#  ('併せ', 'て'): ['行う'],
#  ('て', '行う'): ['べき'],
#  ('行う', 'べき'): ['で'],
#  ('べき', 'で'): ['ある'],
#  ('で', 'ある'): ['。'],
#  ('ある', '。'): ['特に'],
#  ('。', '特に'): ['、'],
#  ('特に', '、'): ['政治家'],
#  ('、', '政治家'): ['が'],
#  ('政治家', 'が'): ['関与'],
#  ('が', '関与'): ['する'],
#  ('関与', 'する'): ['プロジェクト'],
#  ('する', 'プロジェクト'): ['担当'],
#  ('プロジェクト', '担当'): ['者'],
#  ('担当', '者'): ['に'],
#  ('者', 'に'): ['、'],
#  ('に', '、'): ['不正'],
#  ('、', '不正'): ['を'],
#  ('不正', 'を'): ['疑わ'],
#  ('を', '疑わ'): ['れ'],
#  ('疑わ', 'れ'): ['て'],
#  ('れ', 'て'): ['然るべき'],
#  ('て', '然るべき'): ['ケース'],
#  ('然るべき', 'ケース'): ['が'],
#  ('ケース', 'が'): ['多数'],
#  ('が', '多数'): ['存在'],
#  ('多数', '存在'): ['する'],
#  ('存在', 'する'): ['と'],
#  ('する', 'と'): ['聞い'],
#  ('と', '聞い'): ['て'],
#  ('聞い', 'て'): ['いる'],
#  ('いる', '。'): ['真面目', 'お詫び'],
#  ('。', '真面目'): ['に'],
#  ('真面目', 'に'): ['働い', '頑張っ'],
#  ('に', '働い'): ['て'],
#  ('働い', 'て'): ['いれ'],
#  ('て', 'いれ'): ['ば'],
#  ('いれ', 'ば'): ['出世'],
#  ('ば', '出世'): ['コース'],
#  ('出世', 'コース'): ['だっ'],
#  ('コース', 'だっ'): ['た'],
#  ('だっ', 'た'): ['のに'],
#  ('た', 'のに'): ['ね'],
#  ('のに', 'ね'): ['。'],
#  ('。', '官僚'): ['の', 'は'],
#  ('の', 'この'): ['事件'],
#  ('この', '事件'): ['は'],
#  ('事件', 'は'): ['、', 'どう'],
#  ('、', '支援金'): ['自体'],
#  ('支援金', '自体'): ['を'],
#  ('自体', 'を'): ['ちゃぶ台返し'],
#  ('を', 'ちゃぶ台返し'): ['する'],
#  ('ちゃぶ台返し', 'する'): ['よう'],
#  ('する', 'よう'): ['な'],
#  ('な', '重'): ['大事件'],
#  ('重', '大事件'): ['で'],
#  ('大事件', 'で'): ['、'],
#  ('で', '、'): ['まさか'],
#  ('、', 'まさか'): ['、'],
#  ('まさか', '、'): ['の'],
#  ('、', 'の'): ['事件'],
#  ('の', '事件'): ['です'],
#  ('事件', 'です'): ['が'],
#  ('です', 'が'): ['、'],
#  ('が', '、'): ['恐らく', 'こう'],
#  ('、', '恐らく'): ['、'],
#  ('恐らく', '、'): ['悪'],
#  ('、', '悪'): ['目立ち', '目立ち'],
#  ('悪', '目立ち'): ['し', 'し'],
#  ('目立ち', 'し'): ['て', 'なかっ'],
#  ('し', 'て'): ['、', '二度と', 'もらい', 'いる'],
#  ('て', '、'): ['チク'],
#  ('、', 'チク'): ['られ'],
#  ('チク', 'られ'): ['た'],
#  ('られ', 'た'): ['か'],
#  ('た', 'か'): ['何'],
#  ('か', '何'): ['か'],
#  ('何', 'か'): ['で'],
#  ('か', 'で'): ['露見'],
#  ('で', '露見'): ['し'],
#  ('露見', 'し'): ['なかっ', 'なかっ'],
#  ('し', 'なかっ'): ['た', 'たら', 'た'],
#  ('なかっ', 'た'): ['と', 'と'],
#  ('た', 'と'): ['思い', '思い'],
#  ('と', '思い'): ['ます', 'ます', 'ます', 'ます'],
#  ('思い', 'ます'): ['。', 'が', 'ので', '。'],
#  ('ます', '。'): ['もし', '今回', 'コロナ禍'],
#  ('。', 'もし'): ['、'],
#  ('もし', '、'): ['悪'],
#  ('なかっ', 'たら'): ['、'],
#  ('たら', '、'): ['露見'],
#  ('、', '露見'): ['し'],
#  ('ます', 'が'): ['、'],
#  ('、', 'こう'): ['いっ'],
#  ('こう', 'いっ'): ['た'],
#  ('いっ', 'た'): ['事件'],
#  ('た', '事件'): ['の'],
#  ('事件', 'の'): ['場合'],
#  ('の', '場合'): ['、'],
#  ('場合', '、'): ['判決'],
#  ('、', '判決'): ['は'],
#  ('判決', 'は'): ['軽い'],
#  ('は', '軽い'): ['と'],
#  ('軽い', 'と'): ['思い'],
#  ('ます', 'ので'): ['、'],
#  ('ので', '、'): ['詐欺事件'],
#  ('、', '詐欺事件'): ['は'],
#  ('詐欺事件', 'は'): ['、'],
#  ('、', 'その'): ['額'],
#  ('その', '額'): ['の'],
#  ('額', 'の'): ['１'],
#  ('の', '１'): ['０'],
#  ('１', '０'): ['倍'],
#  ('０', '倍'): ['返し'],
#  ('倍', '返し'): ['など'],
#  ('返し', 'など'): ['の'],
#  ('など', 'の'): ['罰則'],
#  ('の', '罰則'): ['を'],
#  ('罰則', 'を'): ['作っ'],
#  ('を', '作っ'): ['て'],
#  ('作っ', 'て'): ['欲しい'],
#  ('て', '欲しい'): ['です'],
#  ('欲しい', 'です'): ['。'],
#  ('です', '。'): ['盗撮'],
#  ('。', '盗撮'): ['事件', '容疑者'],
#  ('盗撮', '事件'): ['は'],
#  ('は', 'どう'): ['なっ'],
#  ('どう', 'なっ'): ['た'],
#  ('なっ', 'た'): ['の'],
#  ('た', 'の'): ['か'],
#  ('の', 'か'): ['な'],
#  ('か', 'な'): ['？'],
#  ('な', '？'): ['こちら'],
#  ('？', 'こちら'): ['は'],
#  ('こちら', 'は'): ['もみ消し'],
#  ('は', 'もみ消し'): ['です'],
#  ('もみ消し', 'です'): ['か'],
#  ('です', 'か'): ['？'],
#  ('か', '？'): ['氷山の一角'],
#  ('？', '氷山の一角'): ['みせしめ'],
#  ('氷山の一角', 'みせしめ'): ['で'],
#  ('みせしめ', 'で'): ['厳罰'],
#  ('で', '厳罰'): ['に'],
#  ('厳罰', 'に'): ['し'],
#  ('に', 'し'): ['て'],
#  ('て', '二度と'): ['社会復帰'],
#  ('二度と', '社会復帰'): ['でき'],
#  ('社会復帰', 'でき'): ['ない'],
#  ('でき', 'ない'): ['とこ'],
#  ('ない', 'とこ'): ['まで'],
#  ('とこ', 'まで'): ['追い込ん'],
#  ('まで', '追い込ん'): ['で'],
#  ('追い込ん', 'で'): ['も'],
#  ('で', 'も'): ['いい'],
#  ('も', 'いい'): ['と'],
#  ('いい', 'と'): ['思い'],
#  ('。', '今回'): ['の'],
#  ('の', '件'): ['は'],
#  ('件', 'は'): ['、'],
#  ('、', '国民'): ['を'],
#  ('国民', 'を'): ['なめ'],
#  ('を', 'なめ'): ['すぎ'],
#  ('なめ', 'すぎ'): ['て'],
#  ('すぎ', 'て'): ['ます'],
#  ('て', 'ます'): ['し'],
#  ('ます', 'し'): ['、'],
#  ('し', '、'): ['真面目'],
#  ('、', '真面目'): ['に'],
#  ('に', '頑張っ'): ['て'],
#  ('頑張っ', 'て'): ['いる'],
#  ('いる', '官僚'): ['の'],
#  ('の', '信用'): ['を'],
#  ('信用', 'を'): ['完全'],
#  ('を', '完全'): ['に'],
#  ('完全', 'に'): ['失墜'],
#  ('に', '失墜'): ['さ'],
#  ('失墜', 'さ'): ['せ'],
#  ('さ', 'せ'): ['まし'],
#  ('せ', 'まし'): ['た'],
#  ('まし', 'た'): ['。'],
#  ('た', '。'): ['官僚', 'そういう'],
#  ('官僚', 'は'): ['自民党'],
#  ('は', '自民党'): ['の'],
#  ('自民党', 'の'): ['延長'],
#  ('の', '延長'): ['みたい'],
#  ('延長', 'みたい'): ['な'],
#  ('みたい', 'な'): ['もの'],
#  ('な', 'もの'): ['だ'],
#  ('もの', 'だ'): ['から'],
#  ('だ', 'から'): ['バレ'],
#  ('から', 'バレ'): ['なきゃ'],
#  ('バレ', 'なきゃ'): ['何'],
#  ('なきゃ', '何'): ['でも'],
#  ('何', 'でも'): ['有り'],
#  ('でも', '有り'): ['何'],
#  ('有り', '何'): ['でしょ'],
#  ('何', 'でしょ'): ['！'],
#  ('でしょ', '！'): ['？'],
#  ('！', '？'): ['不正受給'],
#  ('？', '不正受給'): ['とか'],
#  ('不正受給', 'とか'): ['トイレ'],
#  ('とか', 'トイレ'): ['覗き'],
#  ('トイレ', '覗き'): ['とか'],
#  ('覗き', 'とか'): ['、'],
#  ('とか', '、'): ['小物'],
#  ('、', '小物'): ['は'],
#  ('小物', 'は'): ['いい'],
#  ('は', 'いい'): ['から'],
#  ('いい', 'から'): ['、'],
#  ('から', '、'): ['東芝', '左遷', '省'],
#  ('、', '東芝'): ['の'],
#  ('東芝', 'の'): ['総会'],
#  ('の', '総会'): ['で'],
#  ('総会', 'で'): ['不当'],
#  ('で', '不当'): ['介入'],
#  ('不当', '介入'): ['し'],
#  ('介入', 'し'): ['た'],
#  ('し', 'た'): ['大物', '。'],
#  ('た', '大物'): ['を'],
#  ('大物', 'を'): ['、'],
#  ('を', '、'): ['省内'],
#  ('、', '省内'): ['で'],
#  ('省内', 'で'): ['コッソリ'],
#  ('で', 'コッソリ'): ['で'],
#  ('コッソリ', 'で'): ['構わ'],
#  ('で', '構わ'): ['ない'],
#  ('構わ', 'ない'): ['から'],
#  ('ない', 'から'): ['、'],
#  ('、', '左遷'): ['し'],
#  ('左遷', 'し'): ['て'],
#  ('て', 'もらい'): ['たい'],
#  ('もらい', 'たい'): ['。'],
#  ('たい', '。'): ['経産省'],
#  ('。', '経産省'): ['は'],
#  ('経産省', 'は'): ['安倍政権'],
#  ('は', '安倍政権'): ['以来'],
#  ('安倍政権', '以来'): ['、'],
#  ('以来', '、'): ['政権'],
#  ('、', '政権'): ['中枢'],
#  ('政権', '中枢'): ['に'],
#  ('中枢', 'に'): ['入り込み'],
#  ('に', '入り込み'): ['、'],
#  ('入り込み', '、'): ['財務省'],
#  ('、', '財務省'): ['を'],
#  ('財務省', 'を'): ['駆逐'],
#  ('を', '駆逐'): ['し'],
#  ('駆逐', 'し'): ['た'],
#  ('。', 'そういう'): ['事'],
#  ('そういう', '事'): ['から'],
#  ('事', 'から'): ['、'],
#  ('、', '省'): ['全体'],
#  ('省', '全体'): ['に'],
#  ('全体', 'に'): ['驕り'],
#  ('に', '驕り'): ['の'],
#  ('驕り', 'の'): ['気分'],
#  ('の', '気分'): ['が'],
#  ('気分', 'が'): ['蔓延'],
#  ('が', '蔓延'): ['し'],
#  ('蔓延', 'し'): ['て'],
#  ('いる', 'の'): ['で'],
#  ('の', 'で'): ['は'],
#  ('で', 'は'): ['ない'],
#  ('は', 'ない'): ['か'],
#  ('ない', 'か'): ['。'],
#  ('か', '。'): ['盗撮'],
#  ('盗撮', '容疑者'): ['や'],
#  ('容疑者', 'や'): ['今回'],
#  ('や', '今回'): ['の'],
#  ('の', '詐欺行為'): ['と'],
#  ('詐欺行為', 'と'): ['いい'],
#  ('と', 'いい'): ['、'],
#  ('いい', '、'): ['一部'],
#  ('、', '一部'): ['の'],
#  ('一部', 'の'): ['職員'],
#  ('の', '職員'): ['と'],
#  ('職員', 'と'): ['は'],
#  ('と', 'は'): ['言え'],
#  ('は', '言え'): ['、'],
#  ('言え', '、'): ['綱紀'],
#  ('、', '綱紀'): ['が'],
#  ('綱紀', 'が'): ['緩ん'],
#  ('が', '緩ん'): ['で'],
#  ('緩ん', 'で'): ['いる'],
#  ('で', 'いる'): ['。'],
#  ('。', 'お詫び'): ['として'],
#  ('お詫び', 'として'): ['、'],
#  ('として', '、'): ['数'],
#  ('、', '数'): ['兆'],
#  ('数', '兆'): ['円'],
#  ('兆', '円'): ['規模の経済'],
#  ('円', '規模の経済'): ['再建'],
#  ('規模の経済', '再建'): ['政策'],
#  ('再建', '政策'): ['を'],
#  ('政策', 'を'): ['お願い'],
#  ('を', 'お願い'): ['し'],
#  ('お願い', 'し'): ['ます'],
#  ('し', 'ます'): ['。'],
#  ('。', 'コロナ禍'): ['の'],
#  ('コロナ禍', 'の'): ['せい'],
#  ('の', 'せい'): ['で'],
#  ('せい', 'で'): ['多く'],
#  ('で', '多く'): ['の'],
#  ('多く', 'の'): ['企業'],
#  ('の', '企業'): ['や'],
#  ('企業', 'や'): ['個人'],
#  ('や', '個人'): ['が'],
#  ('個人', 'が'): ['経済的'],
#  ('が', '経済的'): ['に'],
#  ('経済的', 'に'): ['困っ'],
#  ('に', '困っ'): ['て'],
#  ('困っ', 'て'): ['い'],
#  ('て', 'い'): ['ます'],
#  ('い', 'ます'): ['。']}

# %%
count = 0  # 文のカウンタ
num= 100  # 生成する文の数
sentence = ""
sentences = pd.DataFrame(columns=['自動生成文'])
w1, w2  = random.choice(list(markov.keys())) # 2単語をランダムに選ぶ
while count < num:
    try:
        tmp = random.choice(markov[(w1, w2)])  # 2単語に続く候補の中からランダムに選択する
    except:
        pass
    sentence += tmp  # 文に１単語追加
    if(tmp=='。'):  # '。' があったら
        sentences.loc[count] = [sentence]
        count += 1  # 文のカウンタを＋１
        sentence = ""  # 文を格納する変数
    w1, w2 = w2, tmp  # １単語スライド
sentences.to_csv(white+'03_CreateText/'+os.path.basename(p))
